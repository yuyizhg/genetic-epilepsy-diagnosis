# %% [markdown]
# # Step 1 Clean the synthetic dataset
#
# *   The sythetic dataset uses llama embedding and k-means clustering, with 9:1 Ratio: 2 of 60%, 2 of 70%, 2 of 80%, 2 of 90% randomly selected symptoms and 1 of 100% case.
# *   Remove the cases with 0 symptom in the generated synthetic dataset.
# *   Divide all cases into 80% and 20%

# %%
import os, json, math, random, itertools
from collections import defaultdict, Counter
from pathlib import Path
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')

# !ls "/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311"
# Out:
# Mounted at /content/drive
# Clinical_cohort.gsheet
# clinical_symptom_cluster_assignments.csv
# label_map.json
# pubmed_clinical_symptom_cluster_assignments.csv
# PUBMED_cohort.xlsx
# pubmed_symptom_cluster_assignments.csv
# split_summary.csv
# symptom_vocab.json
# synthetic_data.json
# synthetic_data_summary_table.csv
# synthetic_data_summary_table.gsheet
# test-cases-PUBMED-Stanford-combined-11-2025-deleted12cases-cleaned.xlsx
# train.jsonl
# val.jsonl
# xgb_checkpoints
# xgb_checkpoints_params_screening
# XGBoost_Ximing_28Nov25.ipynb

# %%
from pathlib import Path
import random
# -------- CONFIG --------
INPUT_PATH = Path("/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/synthetic_data.json")
TRAIN_OUT  = Path("/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/train.jsonl")
VAL_OUT    = Path("/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/val.jsonl")
SUMMARY_CSV= Path("/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/split_summary.csv")

GLOBAL_SEED = 42
random.seed(GLOBAL_SEED)
# ------------------------
assert INPUT_PATH.exists(), f"File not found: {INPUT_PATH.resolve()}"
# !head -n 5 "/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/synthetic_data.json"
# Out:
# {"syndrome": "DEVELOPMENTAL AND EPILEPTIC ENCEPHALOPATHY 9; DEE9", "coverage_pct": 50, "case_type": "50%", "rep": 1, "n_total_symptoms": 17, "n_selected": 9, "symptom_ids": [77, 109, 249, 717, 870, 2537, 6267, 6959, 9751]}
# {"syndrome": "DEVELOPMENTAL AND EPILEPTIC ENCEPHALOPATHY 9; DEE9", "coverage_pct": 50, "case_type": "50%", "rep": 2, "n_total_symptoms": 17, "n_selected": 9, "symptom_ids": [77, 109, 249, 717, 2537, 6267, 7881, 8951, 9009]}
# {"syndrome": "DEVELOPMENTAL AND EPILEPTIC ENCEPHALOPATHY 9; DEE9", "coverage_pct": 50, "case_type": "50%", "rep": 3, "n_total_symptoms": 17, "n_selected": 9, "symptom_ids": [77, 249, 717, 870, 1027, 1990, 6069, 7881, 9751]}
# {"syndrome": "DEVELOPMENTAL AND EPILEPTIC ENCEPHALOPATHY 9; DEE9", "coverage_pct": 50, "case_type": "50%", "rep": 4, "n_total_symptoms": 17, "n_selected": 9, "symptom_ids": [109, 249, 717, 962, 1027, 2537, 6090, 6959, 9751]}
# {"syndrome": "DEVELOPMENTAL AND EPILEPTIC ENCEPHALOPATHY 9; DEE9", "coverage_pct": 50, "case_type": "50%", "rep": 5, "n_total_symptoms": 17, "n_selected": 9, "symptom_ids": [77, 717, 870, 962, 1990, 2537, 6069, 6267, 7881]}

# %%
import os, json, math, random, itertools
from collections import defaultdict, Counter
import pandas as pd

# === Load (JSON first; if it fails, parse as JSONL) ===
def load_json_or_jsonl(path: Path):
    try:
        with open(path, "r", encoding="utf-8") as f:
            return json.load(f)  # a single JSON value (list or dict)
    except json.JSONDecodeError:
        # Fallback: JSON Lines
        rows = []
        with open(path, "r", encoding="utf-8") as f:
            for ln in f:
                ln = ln.strip()
                if not ln:
                    continue
                try:
                    rows.append(json.loads(ln))
                except json.JSONDecodeError:
                    # skip non-JSON lines if any
                    pass
        return rows

data = load_json_or_jsonl(INPUT_PATH)

# %%
import json, math, random
from collections import defaultdict, Counter
import pandas as pd

GLOBAL_SEED = 42
random.seed(GLOBAL_SEED)

# --- Load as JSONL (since your generator writes one record per line) ---
with open(INPUT_PATH, "r", encoding="utf-8") as f:
    data = [json.loads(ln) for ln in f if ln.strip()]

# --- Normalize into {syndrome, symptoms} keys your downstream expects ---
def get_symptoms(d):
    for k in ("symptoms","symptom_ids","features","codes"):
        if k in d:
            return d[k]
    return None

records = []
for r in data:
    syn = r.get("syndrome") or r.get("label") or r.get("disease") or r.get("name") or r.get("condition")
    syms = get_symptoms(r)
    if syn is not None and syms:  # <-- empty list will return False here
        records.append({"syndrome": str(syn), "symptoms": list(syms)})

print(f"Loaded {len(records)} usable records after first filtering.")

# --- Remove zero-symptom cases ---
records = [r for r in records if isinstance(r["symptoms"], list) and len(r["symptoms"]) > 0]
print(f"Loaded {len(records)} usable records after second filtering.")
# Out:
# Loaded 167660 usable records after first filtering.
# Loaded 167660 usable records after second filtering.

# %% [markdown]
# # Step 2 Generate the 80/20 training/validation dataset
#
# *   Each syndrome has 101 samples, split into 80/20 for training/validation. (81 cases for training and 20 cases for validation)

# %%
# --- Group by syndrome ---
group_by_syndrome = defaultdict(list)
for r in records:
    group_by_syndrome[r["syndrome"]].append(r)

# --- Per-syndrome 80/20 split (floor to train; keep both non-empty if n>=2) ---
train, val = [], []
for syn, cases in group_by_syndrome.items():
    rnd = random.Random(GLOBAL_SEED + (hash(syn) % 1_000_000))
    shuffled = cases[:]
    rnd.shuffle(shuffled)
    n = len(shuffled)
    n_train = max(1, int(math.floor(0.8 * n))) if n > 1 else 1
    if n >= 2 and n_train == n:
        n_train = n - 1
    train.extend(shuffled[:n_train])
    val.extend(shuffled[n_train:])

def write_jsonl(path, rows):
    with open(path, "w", encoding="utf-8") as f:
        for r in rows:
            f.write(json.dumps(r, ensure_ascii=False) + "\n")

write_jsonl(TRAIN_OUT, train)
write_jsonl(VAL_OUT, val)

# --- Summary CSV ---
def summarize(rows):
    c = Counter(r["syndrome"] for r in rows)
    return pd.DataFrame([{"syndrome": k, "n": v} for k, v in sorted(c.items(), key=lambda x: (-x[1], x[0]))])

summary_all = summarize(records).rename(columns={"n":"n_total"})
summary_tr  = summarize(train).rename(columns={"n":"n_train"})
summary_va  = summarize(val).rename(columns={"n":"n_val"})
summary = summary_all.merge(summary_tr, on="syndrome", how="left").merge(summary_va, on="syndrome", how="left")
summary[["n_train","n_val"]] = summary[["n_train","n_val"]].fillna(0).astype(int)
summary["train_ratio"] = (summary["n_train"] / summary["n_total"]).round(3)
summary["val_ratio"]   = (summary["n_val"]   / summary["n_total"]).round(3)
summary = summary.sort_values(["n_total","syndrome"], ascending=[False, True]).reset_index(drop=True)
summary.to_csv(SUMMARY_CSV, index=False)

print("✅ Preprocessing done.")
print("Train:", len(train), "→", TRAIN_OUT)
print("Val:  ", len(val),   "→", VAL_OUT)
print("Summary CSV:", SUMMARY_CSV)

summary.head(10)
# Out:
# ✅ Preprocessing done.
# Train: 132800 → /content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/train.jsonl
# Val:   34860 → /content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/val.jsonl
# Summary CSV: /content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/split_summary.csv
#                                             syndrome  n_total  n_train  n_val  \
# 0        2,4-DIENOYL-CoA REDUCTASE DEFICIENCY; DECRD      101       80     21
# 1       2-METHYLBUTYRYL-CoA DEHYDROGENASE DEFICIENCY      101       80     21
# 2  3-HYDROXY-3-METHYLGLUTARYL-CoA LYASE DEFICIENC...      101       80     21
# 3         3-HYDROXYACYL-CoA DEHYDROGENASE DEFICIENCY      101       80     21
# 4  3-HYDROXYISOBUTYRYL-CoA HYDROLASE DEFICIENCY; ...      101       80     21
# 5  3-METHYLCROTONYL-CoA CARBOXYLASE 1 DEFICIENCY;...      101       80     21
# 6  3-METHYLCROTONYL-CoA CARBOXYLASE 2 DEFICIENCY;...      101       80     21
# 7  3-METHYLGLUTACONIC ACIDURIA WITH DEAFNESS, ENC...      101       80     21
# 8         3-METHYLGLUTACONIC ACIDURIA, TYPE I; MGCA1      101       80     21
# 9        3-METHYLGLUTACONIC ACIDURIA, TYPE IX; MGCA9      101       80     21
#
#    train_ratio  val_ratio
# 0        0.792      0.208
# 1        0.792      0.208
# 2        0.792      0.208
# 3        0.792      0.208
# 4        0.792      0.208
# 5        0.792      0.208
# 6        0.792      0.208
# 7        0.792      0.208
# 8        0.792      0.208
# 9        0.792      0.208

# %% [markdown]
# # Step 3: Vectorize - build bag-of-symptoms
# *   Look at training data only → collect all unique symptom IDs = sym_vocab.
# *   Convert each training example into a vector of 0s and 1s of length len(sym_vocab).
# *   When converting validation examples, use the same sym_vocab. If a symptom appears in validation but not in training, we simply ignore it (treat as unseen).
#
#
# ---
# Gives us:
# *   A feature matrix X_train of shape [num_training_cases, num_unique_symptoms]
# *   A label vector y_train with the syndrome for each row
# *   **Symptom_vocab.json** saves the complete list of unique symptom IDs seen in the training dataset, in sorted order.
# *   **label_map.json** maps each syndrome label (string name) to its numeric index used by the model.

# %%
INPUT_PATH = Path("/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/synthetic_data.json")
TRAIN_OUT  = Path("/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/train.jsonl")
VAL_OUT    = Path("/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/val.jsonl")

# %%
import json
from scipy.sparse import csr_matrix
import numpy as np
from sklearn.preprocessing import LabelEncoder
from pathlib import Path

def read_jsonl(path):
    rows = []
    with open(path, "r", encoding="utf-8") as f:
        for ln in f:
            if ln.strip():
                rows.append(json.loads(ln))
    return rows

train_rows = read_jsonl(TRAIN_OUT)
val_rows   = read_jsonl(VAL_OUT)

# Build symptom vocabulary from TRAINING dataset ONLY (avoid leakage)
sym_vocab = sorted({sid for r in train_rows for sid in r["symptoms"]})
sym_index = {sid:i for i, sid in enumerate(sym_vocab)}

def rows_to_bow(rows):
    indptr, indices, data = [0], [], []
    labels = []
    for r in rows:
        cols = [sym_index[sid] for sid in r["symptoms"] if sid in sym_index]
        cols = sorted(set(cols))
        indices.extend(cols)
        data.extend([1]*len(cols))
        indptr.append(len(indices))
        labels.append(r["syndrome"])
    X = csr_matrix((data, indices, indptr), shape=(len(rows), len(sym_vocab)), dtype=np.float32)
    return X, labels

X_train, y_train = rows_to_bow(train_rows)
X_val,   y_val   = rows_to_bow(val_rows)

le = LabelEncoder().fit(y_train)
y_train_enc = le.transform(y_train)
y_val_enc   = le.transform(y_val)  # safe since per-syndrome split keeps labels present in train

print("X_train:", X_train.shape, "X_val:", X_val.shape, "classes:", len(le.classes_))

# Save vocab & label map
BASE_DIR = INPUT_PATH.parent

VOCAB_PATH = BASE_DIR / "symptom_vocab.json"
LABEL_MAP_PATH = BASE_DIR / "label_map.json"

with open(VOCAB_PATH, "w", encoding="utf-8") as f:
    json.dump(sym_vocab, f)

with open(LABEL_MAP_PATH, "w", encoding="utf-8") as f:
    json.dump({cls: int(i) for i, cls in enumerate(le.classes_)}, f, ensure_ascii=False)

print("Saved:", VOCAB_PATH)
print("Saved:", LABEL_MAP_PATH)
# Out:
# X_train: (132800, 9883) X_val: (34860, 9883) classes: 1660
# Saved: /content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/symptom_vocab.json
# Saved: /content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/label_map.json

# %% [markdown]
# # Step 4: Train XGBoost multi-class & evaluate
# *   Use 5-fold cross-validation here.
# *   Because the dataset is highly imbalanced and tiny per class, we cannot just randomly split samples. Use a StratifiedKFold or StratifiedGroupKFold here to ensure every fold contains roughly the same class proportions.This prevents some folds from missing rare syndromes entirely.

# %%
# !python3 -m pip uninstall -y xgboost
# !python3 -m pip install --no-cache-dir xgboost==3.1.1
# Out:
# Found existing installation: xgboost 2.1.1
# Uninstalling xgboost-2.1.1:
#   Successfully uninstalled xgboost-2.1.1
# Collecting xgboost==3.1.1
#   Downloading xgboost-3.1.1-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (2.27.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost==3.1.1) (1.16.3)
# Downloading xgboost-3.1.1-py3-none-manylinux_2_28_x86_64.whl (115.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 MB 154.7 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-3.1.1

# %%
import xgboost as xgb
print("XGBoost version:", xgb.__version__)  # should be at least 3.1.1 (Colab default right now)
# Out:
# XGBoost version: 3.1.2

# %% [markdown]
# Parameter screening
#
#
# ---
#
# | Hyperparameter   | Old Value | Default (if omitted) | New Search Range |
# | ---------------- | --------- | -------------------- | ---------------- |
# | max_depth        | **4**     | —                    | [3, 4, 5]        |
# | min_child_weight | —         | **1**                | [1, 5, 10]       |
# | gamma            | —         | **0**                | [0, 0.5, 1.0]    |
# | subsample        | **0.9**   | —                    | [0.6, 0.8, 1.0]  |
# | colsample_bytree | **0.9**   | —                    | [0.5, 0.7, 0.9]  |
# | reg_lambda       | **1.0**   | —                    | [1.0, 2.0, 5.0]  |
# | reg_alpha        | —         | **0.0**              | [0.0, 0.1, 1.0]  |
# | learning_rate    | **0.1**   | —                    | [0.05, 0.1]      |

# %%
import os, re, glob, json, pickle
import numpy as np
from pathlib import Path
from collections import Counter
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
import xgboost as xgb
from xgboost import callback
import itertools

# ========= CONFIG =========
SAVE_DIR = Path("/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints")
SAVE_DIR.mkdir(parents=True, exist_ok=True)

NUM_CLASS = len(le.classes_)     # from your LabelEncoder on y_train
N_BOOST_ROUNDS = 1000
EARLY_STOPPING_ROUNDS = 100
CHECKPOINT_EVERY = 250
RANDOM_STATE = 42
N_SPLITS = 5
# ==========================

# ---- Version-agnostic periodic saver ----
class PeriodicSaver(callback.TrainingCallback):
    """Save booster every `every` rounds to SAVE_DIR / f'{name}_{iter:04d}.json'."""
    def __init__(self, save_dir: Path, name: str, every: int):
        self.save_dir = Path(save_dir)
        self.name = name
        self.every = int(every)

    def after_iteration(self, model, epoch: int, evals_log) -> bool:
        it = epoch + 1
        if it % self.every == 0:
            path = self.save_dir / f"{self.name}_{it:04d}.json"
            model.save_model(str(path))
            print(f"[checkpoint] saved {path}")
        return False

def latest_checkpoint_for_fold(save_dir: Path, fold: int):
    """Return path to latest checkpoint (json) for this fold, or None."""
    pattern = str(save_dir / f"xgb_fold{fold}_*.json")
    candidates = glob.glob(pattern)
    if not candidates:
        return None
    best, best_iter = None, -1
    rx = re.compile(rf"xgb_fold{fold}_(\d+)\.json$")
    for p in candidates:
        m = rx.search(os.path.basename(p))
        if m:
            it = int(m.group(1))
            if it > best_iter:
                best_iter, best = it, p
    return best

# Adjust folds if rare class too small
min_per_class = min(Counter(y_train_enc).values())
actual_splits = min(N_SPLITS, max(2, min_per_class))
print(f"Using {actual_splits}-fold CV (min per class = {min_per_class})")

kf = StratifiedKFold(n_splits=actual_splits, shuffle=True, random_state=RANDOM_STATE)

# ============================================================
#  PARAM GRID (EDIT FROM HERE)
# ============================================================
param_grid = {
    "max_depth":        [4, 6],
    "learning_rate":    [0.05, 0.1],
    "min_child_weight": [1, 5],
    "gamma":            [0],
    "subsample":        [0.9],
    "colsample_bytree": [0.9],
    "reg_lambda":       [1.0],
}

# Create all combinations
param_keys = list(param_grid.keys())
param_combos = list(itertools.product(*param_grid.values()))

print(f"\n🔍 Total param combinations: {len(param_combos)}")
print("Grid:", param_grid)

best_params = None
best_score = -1

# ============================================================
#   OUTER LOOP — TRY EACH PARAMETER COMBINATION
# ============================================================
for combo_idx, combo in enumerate(param_combos, 1):
    print("\n" + "="*80)
    print(f"🔎 Parameter Set {combo_idx}/{len(param_combos)}")

    # Build this run's param dictionary
    params = {
        "objective": "multi:softprob",
        "num_class": NUM_CLASS,
        "eval_metric": "mlogloss",
        "tree_method": "hist",
        "device": "cuda",
        "seed": RANDOM_STATE,
    }

    # Insert this combo’s parameters
    for key, val in zip(param_keys, combo):
        params[key] = val

    print("Using params:", params)

    # Store fold results here
    fold_accs = []

    # ====================================================
    #   INNER LOOP — K-FOLD TRAINING FOR THIS PARAM COMBO
    # ====================================================
    for fold, (train_idx, val_idx) in enumerate(kf.split(X_train, y_train_enc), 1):
        print(f"\n===== ParamSet {combo_idx} — Fold {fold} =====")
        X_tr, X_va = X_train[train_idx], X_train[val_idx]
        y_tr, y_va = y_train_enc[train_idx], y_train_enc[val_idx]

        dtrain = xgb.DMatrix(X_tr, label=y_tr)
        dvalid = xgb.DMatrix(X_va, label=y_va)
        evals = [(dtrain, "train"), (dvalid, "valid")]

        # SEPARATE CHECKPOINT NAMESPACE per param-set
        fold_save_dir = SAVE_DIR / f"paramset{combo_idx}"
        fold_save_dir.mkdir(exist_ok=True)
        saver_cb = PeriodicSaver(fold_save_dir, name=f"xgb_fold{fold}", every=CHECKPOINT_EVERY)

        booster = xgb.train(
            params=params,
            dtrain=dtrain,
            num_boost_round=N_BOOST_ROUNDS,
            evals=evals,
            early_stopping_rounds=EARLY_STOPPING_ROUNDS,
            callbacks=[saver_cb],
            verbose_eval=False,
        )

        # Predict & compute accuracy
        iteration_range = (0, booster.best_iteration+1) if booster.best_iteration is not None else None
        y_prob = booster.predict(dvalid, iteration_range=iteration_range)
        y_pred = np.argmax(y_prob, axis=1)
        acc = accuracy_score(y_va, y_pred)
        fold_accs.append(acc)

        print(f"Fold {fold} accuracy: {acc:.4f}")

    # Mean accuracy for this param set
    mean_acc = np.mean(fold_accs)
    print(f"\n📌 Param Set {combo_idx} Mean CV Accuracy: {mean_acc:.4f}")

    # Track best
    if mean_acc > best_score:
        best_score = mean_acc
        best_params = params

# ============================================================
#  BEST PARAMETERS FOUND
# ============================================================
print("\n" + "="*80)
print(f"🏆 BEST PARAMS FOUND:")
print(best_params)
print(f"🏆 BEST MEAN CV ACCURACY: {best_score:.4f}")
print("="*80)
# Out:
# Using 5-fold CV (min per class = 80)
#
# 🔍 Total param combinations: 8
# Grid: {'max_depth': [4, 6], 'learning_rate': [0.05, 0.1], 'min_child_weight': [1, 5], 'gamma': [0], 'subsample': [0.9], 'colsample_bytree': [0.9], 'reg_lambda': [1.0]}
#
# ================================================================================
# 🔎 Parameter Set 1/8
# Using params: {'objective': 'multi:softprob', 'num_class': 1660, 'eval_metric': 'mlogloss', 'tree_method': 'hist', 'device': 'cuda', 'seed': 42, 'max_depth': 4, 'learning_rate': 0.05, 'min_child_weight': 1, 'gamma': 0, 'subsample': 0.9, 'colsample_bytree': 0.9, 'reg_lambda': 1.0}
#
# ===== ParamSet 1 — Fold 1 =====
# [checkpoint] saved /content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints_params_screening/paramset1/xgb_fold1_0250.json
# Fold 1 accuracy: 0.9909
#
# ===== ParamSet 1 — Fold 2 =====
# [checkpoint] saved /content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints_params_screening/paramset1/xgb_fold2_0250.json
# Fold 2 accuracy: 0.9910
#
# ===== ParamSet 1 — Fold 3 =====

# %% [markdown]
# **Old model params**

# %%
import os, re, glob, json, pickle
import numpy as np
from pathlib import Path
from collections import Counter
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
import xgboost as xgb
from xgboost import callback

# ========= CONFIG =========
SAVE_DIR = Path("/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints")
SAVE_DIR.mkdir(parents=True, exist_ok=True)

NUM_CLASS = len(le.classes_)     # from your LabelEncoder on y_train
N_BOOST_ROUNDS = 1000            # cap on total trees
EARLY_STOPPING_ROUNDS = 100      # stop if no improvement
CHECKPOINT_EVERY = 250           # save every N rounds
RANDOM_STATE = 42
N_SPLITS = 5
# ==========================

# ---- Version-agnostic periodic saver ----
class PeriodicSaver(callback.TrainingCallback):
    """Save booster every `every` rounds to SAVE_DIR / f'{name}_{iter:04d}.json'."""
    def __init__(self, save_dir: Path, name: str, every: int):
        self.save_dir = Path(save_dir)
        self.name = name
        self.every = int(every)

    def after_iteration(self, model, epoch: int, evals_log) -> bool:
        it = epoch + 1
        if it % self.every == 0:
            path = self.save_dir / f"{self.name}_{it:04d}.json"
            model.save_model(str(path))
            print(f"[checkpoint] saved {path}")
        return False  # continue training

def latest_checkpoint_for_fold(save_dir: Path, fold: int):
    """Return path to latest checkpoint (json) for this fold, or None."""
    pattern = str(save_dir / f"xgb_fold{fold}_*.json")
    candidates = glob.glob(pattern)
    if not candidates:
        return None
    best, best_iter = None, -1
    rx = re.compile(rf"xgb_fold{fold}_(\d+)\.json$")
    for p in candidates:
        m = rx.search(os.path.basename(p))
        if m:
            it = int(m.group(1))
            if it > best_iter:
                best_iter, best = it, p
    return best

# Adjust folds if the rarest class is too small
min_per_class = min(Counter(y_train_enc).values())
actual_splits = min(N_SPLITS, max(2, min_per_class))
print(f"Using {actual_splits}-fold CV (min per class = {min_per_class})")

kf = StratifiedKFold(n_splits=actual_splits, shuffle=True, random_state=RANDOM_STATE)
fold_accs = []

# Common XGBoost params
params = {
    "objective": "multi:softprob",
    "num_class": NUM_CLASS,
    "eval_metric": "mlogloss",
    "max_depth": 4,
    "learning_rate": 0.1,
    "subsample": 0.9,
    "colsample_bytree": 0.9,
    "reg_lambda": 1.0,
    "tree_method": "hist",
    "device": "cuda",
    "seed": RANDOM_STATE,
}

for fold, (train_idx, val_idx) in enumerate(kf.split(X_train, y_train_enc), 1):
    print(f"\n===== Fold {fold} =====")
    X_tr, X_va = X_train[train_idx], X_train[val_idx]
    y_tr, y_va = y_train_enc[train_idx], y_train_enc[val_idx]

    dtrain = xgb.DMatrix(X_tr, label=y_tr)
    dvalid = xgb.DMatrix(X_va, label=y_va)
    evals = [(dtrain, "train"), (dvalid, "valid")]

    resume_path = latest_checkpoint_for_fold(SAVE_DIR, fold)
    if resume_path:
        print(f"➡️  Resuming from checkpoint: {resume_path}")
    else:
        print("➡️  No checkpoint found; starting fresh.")

    saver_cb = PeriodicSaver(SAVE_DIR, name=f"xgb_fold{fold}", every=CHECKPOINT_EVERY)

    # Train (resume if checkpoint exists)
    booster = xgb.train(
        params=params,
        dtrain=dtrain,
        num_boost_round=N_BOOST_ROUNDS,
        evals=evals,
        early_stopping_rounds=EARLY_STOPPING_ROUNDS,
        callbacks=[saver_cb],
        xgb_model=resume_path if resume_path else None,
        verbose_eval=True
    )

    # Save final model (JSON, portable)
    final_json = SAVE_DIR / f"xgb_fold{fold}_final.json"
    booster.save_model(str(final_json))
    print(f"✅ Saved final model: {final_json}")

    # Predict on this fold's holdout and score
    y_prob = booster.predict(dvalid, iteration_range=(0, booster.best_iteration + 1) if booster.best_iteration is not None else None)
    y_pred = np.argmax(y_prob, axis=1)
    acc = accuracy_score(y_va, y_pred)
    fold_accs.append(acc)
    print(f"Fold {fold} accuracy: {acc:.4f}")
    if booster.best_iteration is not None:
        print(f"Best iteration (early stop): {booster.best_iteration}")

mean_acc, std_acc = np.mean(fold_accs), np.std(fold_accs)
print(f"\nMean CV accuracy: {mean_acc:.4f} ± {std_acc:.4f}")
print(f"All checkpoints & final models in: {SAVE_DIR}")
# Out:
# Using 5-fold CV (min per class = 80)
#
# ===== Fold 1 =====
# ➡️  No checkpoint found; starting fresh.
# [0]	train-mlogloss:6.05866	valid-mlogloss:6.12158
# [1]	train-mlogloss:4.73332	valid-mlogloss:4.85385
# [2]	train-mlogloss:3.35988	valid-mlogloss:3.56924
# [3]	train-mlogloss:2.74918	valid-mlogloss:2.99080
# [4]	train-mlogloss:2.37562	valid-mlogloss:2.63422
# [5]	train-mlogloss:2.09463	valid-mlogloss:2.36640
# [6]	train-mlogloss:1.86480	valid-mlogloss:2.14568
# [7]	train-mlogloss:1.67122	valid-mlogloss:1.95922
# [8]	train-mlogloss:1.50259	valid-mlogloss:1.79446
# [9]	train-mlogloss:1.35688	valid-mlogloss:1.65177
# [10]	train-mlogloss:1.23113	valid-mlogloss:1.52789
# [11]	train-mlogloss:1.11993	valid-mlogloss:1.41753
# [12]	train-mlogloss:1.02177	valid-mlogloss:1.31894
# [13]	train-mlogloss:0.93376	valid-mlogloss:1.23052
# [14]	train-mlogloss:0.85423	valid-mlogloss:1.14956
# [15]	train-mlogloss:0.78337	valid-mlogloss:1.07686
# [16]	train-mlogloss:0.72010	valid-mlogloss:1.01115
# [17]	train-mlogloss:0.66299	valid-mlogloss:0.95118
# [18]	train-mlogloss:0.61109	valid-mlogloss:0.89603
# [19]	train-mlogloss:0.56313	valid-mlogloss:0.84441
# [20]	train-mlogloss:0.51977	valid-mlogloss:0.79746
# [21]	train-mlogloss:0.47729	valid-mlogloss:0.75076
# [22]	train-mlogloss:0.44003	valid-mlogloss:0.70911
# [23]	train-mlogloss:0.40573	valid-mlogloss:0.67047
# [24]	train-mlogloss:0.37328	valid-mlogloss:0.63338
# [25]	train-mlogloss:0.34297	valid-mlogloss:0.59799
# [26]	train-mlogloss:0.31651	valid-mlogloss:0.56649
# [27]	train-mlogloss:0.29184	valid-mlogloss:0.53653
# [28]	train-mlogloss:0.26841	valid-mlogloss:0.50785
# [29]	train-mlogloss:0.24816	valid-mlogloss:0.48229
# [30]	train-mlogloss:0.22978	valid-mlogloss:0.45856
# [31]	train-mlogloss:0.21296	valid-mlogloss:0.43671
# [32]	train-mlogloss:0.19757	valid-mlogloss:0.41603
# [33]	train-mlogloss:0.18354	valid-mlogloss:0.39694
# [34]	train-mlogloss:0.16949	valid-mlogloss:0.37796
# [35]	train-mlogloss:0.15744	valid-mlogloss:0.36098
# [36]	train-mlogloss:0.14646	valid-mlogloss:0.34504
# [37]	train-mlogloss:0.13642	valid-mlogloss:0.33022
# [38]	train-mlogloss:0.12721	valid-mlogloss:0.31626
# [39]	train-mlogloss:0.11875	valid-mlogloss:0.30330
# [40]	train-mlogloss:0.11097	valid-mlogloss:0.29100
# [41]	train-mlogloss:0.10381	valid-mlogloss:0.27950
# [42]	train-mlogloss:0.09722	valid-mlogloss:0.26866
# [43]	train-mlogloss:0.09116	valid-mlogloss:0.25843
# [44]	train-mlogloss:0.08558	valid-mlogloss:0.24886
# [45]	train-mlogloss:0.08044	valid-mlogloss:0.23973
# [46]	train-mlogloss:0.07568	valid-mlogloss:0.23123
# [47]	train-mlogloss:0.07129	valid-mlogloss:0.22321
# [48]	train-mlogloss:0.06725	valid-mlogloss:0.21564
# [49]	train-mlogloss:0.06353	valid-mlogloss:0.20847
# [50]	train-mlogloss:0.06009	valid-mlogloss:0.20172
# [51]	train-mlogloss:0.05694	valid-mlogloss:0.19538
# [52]	train-mlogloss:0.05404	valid-mlogloss:0.18938
# [53]	train-mlogloss:0.05136	valid-mlogloss:0.18388
# [54]	train-mlogloss:0.04889	valid-mlogloss:0.17862
# [55]	train-mlogloss:0.04663	valid-mlogloss:0.17380
# [56]	train-mlogloss:0.04454	valid-mlogloss:0.16928
# [57]	train-mlogloss:0.04261	valid-mlogloss:0.16504
# [58]	train-mlogloss:0.04081	valid-mlogloss:0.16109
# [59]	train-mlogloss:0.03917	valid-mlogloss:0.15736
# [60]	train-mlogloss:0.03765	valid-mlogloss:0.15382
# [61]	train-mlogloss:0.03623	valid-mlogloss:0.15044
# [62]	train-mlogloss:0.03491	valid-mlogloss:0.14732
# [63]	train-mlogloss:0.03369	valid-mlogloss:0.14439
# [64]	train-mlogloss:0.03253	valid-mlogloss:0.14160
# [65]	train-mlogloss:0.03146	valid-mlogloss:0.13896
# [66]	train-mlogloss:0.03045	valid-mlogloss:0.13646
# [67]	train-mlogloss:0.02951	valid-mlogloss:0.13406
# [68]	train-mlogloss:0.02862	valid-mlogloss:0.13174
# [69]	train-mlogloss:0.02778	valid-mlogloss:0.12957
# [70]	train-mlogloss:0.02698	valid-mlogloss:0.12748
# [71]	train-mlogloss:0.02624	valid-mlogloss:0.12551
# [72]	train-mlogloss:0.02553	valid-mlogloss:0.12362
# [73]	train-mlogloss:0.02485	valid-mlogloss:0.12181
# [74]	train-mlogloss:0.02422	valid-mlogloss:0.12008
# [75]	train-mlogloss:0.02360	valid-mlogloss:0.11840
# [76]	train-mlogloss:0.02303	valid-mlogloss:0.11682
# [77]	train-mlogloss:0.02248	valid-mlogloss:0.11526
# [78]	train-mlogloss:0.02196	valid-mlogloss:0.11377
# [79]	train-mlogloss:0.02146	valid-mlogloss:0.11233
# [80]	train-mlogloss:0.02099	valid-mlogloss:0.11098
# [81]	train-mlogloss:0.02055	valid-mlogloss:0.10969
# [82]	train-mlogloss:0.02013	valid-mlogloss:0.10849
# [83]	train-mlogloss:0.01973	valid-mlogloss:0.10732
# [84]	train-mlogloss:0.01935	valid-mlogloss:0.10624
# [85]	train-mlogloss:0.01899	valid-mlogloss:0.10511
# [86]	train-mlogloss:0.01865	valid-mlogloss:0.10408
# [87]	train-mlogloss:0.01833	valid-mlogloss:0.10315
# [88]	train-mlogloss:0.01803	valid-mlogloss:0.10227
# [89]	train-mlogloss:0.01774	valid-mlogloss:0.10141
# [90]	train-mlogloss:0.01748	valid-mlogloss:0.10063
# [91]	train-mlogloss:0.01722	valid-mlogloss:0.09992
# [92]	train-mlogloss:0.01698	valid-mlogloss:0.09924
# [93]	train-mlogloss:0.01676	valid-mlogloss:0.09860
# [94]	train-mlogloss:0.01655	valid-mlogloss:0.09799
# [95]	train-mlogloss:0.01635	valid-mlogloss:0.09742
# [96]	train-mlogloss:0.01617	valid-mlogloss:0.09685
# [97]	train-mlogloss:0.01600	valid-mlogloss:0.09636
# [98]	train-mlogloss:0.01583	valid-mlogloss:0.09589
# [99]	train-mlogloss:0.01568	valid-mlogloss:0.09548
# [100]	train-mlogloss:0.01554	valid-mlogloss:0.09506
# [101]	train-mlogloss:0.01541	valid-mlogloss:0.09466
# [102]	train-mlogloss:0.01528	valid-mlogloss:0.09430
# [103]	train-mlogloss:0.01516	valid-mlogloss:0.09396
# [104]	train-mlogloss:0.01505	valid-mlogloss:0.09365
# [105]	train-mlogloss:0.01494	valid-mlogloss:0.09339
# [106]	train-mlogloss:0.01484	valid-mlogloss:0.09315
# [107]	train-mlogloss:0.01475	valid-mlogloss:0.09289
# [108]	train-mlogloss:0.01466	valid-mlogloss:0.09265
# [109]	train-mlogloss:0.01458	valid-mlogloss:0.09244
# [110]	train-mlogloss:0.01449	valid-mlogloss:0.09225
# [111]	train-mlogloss:0.01442	valid-mlogloss:0.09207
# [112]	train-mlogloss:0.01435	valid-mlogloss:0.09190
# [113]	train-mlogloss:0.01428	valid-mlogloss:0.09174
# [114]	train-mlogloss:0.01422	valid-mlogloss:0.09158
# [115]	train-mlogloss:0.01415	valid-mlogloss:0.09145
# [116]	train-mlogloss:0.01409	valid-mlogloss:0.09130
# [117]	train-mlogloss:0.01404	valid-mlogloss:0.09116
# [118]	train-mlogloss:0.01398	valid-mlogloss:0.09101
# [119]	train-mlogloss:0.01393	valid-mlogloss:0.09090
# [120]	train-mlogloss:0.01388	valid-mlogloss:0.09078
# [121]	train-mlogloss:0.01383	valid-mlogloss:0.09066
# [122]	train-mlogloss:0.01379	valid-mlogloss:0.09057
# [123]	train-mlogloss:0.01374	valid-mlogloss:0.09048
# [124]	train-mlogloss:0.01370	valid-mlogloss:0.09041
# [125]	train-mlogloss:0.01366	valid-mlogloss:0.09033
# [126]	train-mlogloss:0.01362	valid-mlogloss:0.09023
# [127]	train-mlogloss:0.01358	valid-mlogloss:0.09016
# [128]	train-mlogloss:0.01355	valid-mlogloss:0.09010
# [129]	train-mlogloss:0.01351	valid-mlogloss:0.09003
# [130]	train-mlogloss:0.01348	valid-mlogloss:0.08995
# [131]	train-mlogloss:0.01345	valid-mlogloss:0.08989
# [132]	train-mlogloss:0.01342	valid-mlogloss:0.08984
# [133]	train-mlogloss:0.01339	valid-mlogloss:0.08981
# [134]	train-mlogloss:0.01336	valid-mlogloss:0.08975
# [135]	train-mlogloss:0.01333	valid-mlogloss:0.08972
# [136]	train-mlogloss:0.01330	valid-mlogloss:0.08967
# [137]	train-mlogloss:0.01327	valid-mlogloss:0.08962
# [138]	train-mlogloss:0.01325	valid-mlogloss:0.08955
# [139]	train-mlogloss:0.01322	valid-mlogloss:0.08951
# [140]	train-mlogloss:0.01320	valid-mlogloss:0.08949
# [141]	train-mlogloss:0.01318	valid-mlogloss:0.08944
# [142]	train-mlogloss:0.01315	valid-mlogloss:0.08942
# [143]	train-mlogloss:0.01313	valid-mlogloss:0.08938
# [144]	train-mlogloss:0.01311	valid-mlogloss:0.08937
# [145]	train-mlogloss:0.01308	valid-mlogloss:0.08932
# [146]	train-mlogloss:0.01306	valid-mlogloss:0.08928
# [147]	train-mlogloss:0.01304	valid-mlogloss:0.08925
# [148]	train-mlogloss:0.01302	valid-mlogloss:0.08923
# [149]	train-mlogloss:0.01300	valid-mlogloss:0.08920
# [150]	train-mlogloss:0.01298	valid-mlogloss:0.08916
# [151]	train-mlogloss:0.01296	valid-mlogloss:0.08913
# [152]	train-mlogloss:0.01295	valid-mlogloss:0.08913
# [153]	train-mlogloss:0.01293	valid-mlogloss:0.08911
# [154]	train-mlogloss:0.01291	valid-mlogloss:0.08908
# [155]	train-mlogloss:0.01289	valid-mlogloss:0.08904
# [156]	train-mlogloss:0.01288	valid-mlogloss:0.08903
# [157]	train-mlogloss:0.01286	valid-mlogloss:0.08904
# [158]	train-mlogloss:0.01284	valid-mlogloss:0.08902
# [159]	train-mlogloss:0.01283	valid-mlogloss:0.08903
# [160]	train-mlogloss:0.01281	valid-mlogloss:0.08902
# [161]	train-mlogloss:0.01280	valid-mlogloss:0.08901
# [162]	train-mlogloss:0.01278	valid-mlogloss:0.08899
# [163]	train-mlogloss:0.01277	valid-mlogloss:0.08899
# [164]	train-mlogloss:0.01275	valid-mlogloss:0.08898
# [165]	train-mlogloss:0.01274	valid-mlogloss:0.08896
# [166]	train-mlogloss:0.01272	valid-mlogloss:0.08895
# [167]	train-mlogloss:0.01271	valid-mlogloss:0.08895
# [168]	train-mlogloss:0.01270	valid-mlogloss:0.08894
# [169]	train-mlogloss:0.01269	valid-mlogloss:0.08894
# [170]	train-mlogloss:0.01267	valid-mlogloss:0.08893
# [171]	train-mlogloss:0.01266	valid-mlogloss:0.08893
# [172]	train-mlogloss:0.01265	valid-mlogloss:0.08894
# [173]	train-mlogloss:0.01264	valid-mlogloss:0.08893
# [174]	train-mlogloss:0.01262	valid-mlogloss:0.08895
# [175]	train-mlogloss:0.01261	valid-mlogloss:0.08896
# [176]	train-mlogloss:0.01260	valid-mlogloss:0.08895
# [177]	train-mlogloss:0.01259	valid-mlogloss:0.08896
# [178]	train-mlogloss:0.01258	valid-mlogloss:0.08896
# [179]	train-mlogloss:0.01257	valid-mlogloss:0.08895
# [180]	train-mlogloss:0.01256	valid-mlogloss:0.08896
# [181]	train-mlogloss:0.01255	valid-mlogloss:0.08896
# [182]	train-mlogloss:0.01254	valid-mlogloss:0.08895
# [183]	train-mlogloss:0.01253	valid-mlogloss:0.08894
# [184]	train-mlogloss:0.01251	valid-mlogloss:0.08894
# [185]	train-mlogloss:0.01250	valid-mlogloss:0.08895
# [186]	train-mlogloss:0.01249	valid-mlogloss:0.08895
# [187]	train-mlogloss:0.01248	valid-mlogloss:0.08894
# [188]	train-mlogloss:0.01247	valid-mlogloss:0.08895
# [189]	train-mlogloss:0.01246	valid-mlogloss:0.08895
# [190]	train-mlogloss:0.01246	valid-mlogloss:0.08895
# [191]	train-mlogloss:0.01245	valid-mlogloss:0.08893
# [192]	train-mlogloss:0.01244	valid-mlogloss:0.08894
# [193]	train-mlogloss:0.01243	valid-mlogloss:0.08893
# [194]	train-mlogloss:0.01242	valid-mlogloss:0.08894
# [195]	train-mlogloss:0.01241	valid-mlogloss:0.08895
# [196]	train-mlogloss:0.01240	valid-mlogloss:0.08895
# [197]	train-mlogloss:0.01239	valid-mlogloss:0.08895
# [198]	train-mlogloss:0.01238	valid-mlogloss:0.08895
# [199]	train-mlogloss:0.01238	valid-mlogloss:0.08896
# [200]	train-mlogloss:0.01237	valid-mlogloss:0.08896
# [201]	train-mlogloss:0.01236	valid-mlogloss:0.08897
# [202]	train-mlogloss:0.01235	valid-mlogloss:0.08897
# [203]	train-mlogloss:0.01234	valid-mlogloss:0.08898
# [204]	train-mlogloss:0.01234	valid-mlogloss:0.08897
# [205]	train-mlogloss:0.01233	valid-mlogloss:0.08898
# [206]	train-mlogloss:0.01232	valid-mlogloss:0.08899
# [207]	train-mlogloss:0.01231	valid-mlogloss:0.08899
# [208]	train-mlogloss:0.01230	valid-mlogloss:0.08899
# [209]	train-mlogloss:0.01230	valid-mlogloss:0.08901
# [210]	train-mlogloss:0.01229	valid-mlogloss:0.08901
# [211]	train-mlogloss:0.01228	valid-mlogloss:0.08902
# [212]	train-mlogloss:0.01227	valid-mlogloss:0.08902
# [213]	train-mlogloss:0.01227	valid-mlogloss:0.08902
# [214]	train-mlogloss:0.01226	valid-mlogloss:0.08902
# [215]	train-mlogloss:0.01225	valid-mlogloss:0.08902
# [216]	train-mlogloss:0.01225	valid-mlogloss:0.08903
# [217]	train-mlogloss:0.01224	valid-mlogloss:0.08904
# [218]	train-mlogloss:0.01223	valid-mlogloss:0.08905
# [219]	train-mlogloss:0.01223	valid-mlogloss:0.08904
# [220]	train-mlogloss:0.01222	valid-mlogloss:0.08906
# [221]	train-mlogloss:0.01221	valid-mlogloss:0.08906
# [222]	train-mlogloss:0.01221	valid-mlogloss:0.08907
# [223]	train-mlogloss:0.01220	valid-mlogloss:0.08909
# [224]	train-mlogloss:0.01219	valid-mlogloss:0.08908
# [225]	train-mlogloss:0.01219	valid-mlogloss:0.08908
# [226]	train-mlogloss:0.01218	valid-mlogloss:0.08909
# [227]	train-mlogloss:0.01218	valid-mlogloss:0.08910
# [228]	train-mlogloss:0.01217	valid-mlogloss:0.08910
# [229]	train-mlogloss:0.01216	valid-mlogloss:0.08910
# [230]	train-mlogloss:0.01216	valid-mlogloss:0.08911
# [231]	train-mlogloss:0.01215	valid-mlogloss:0.08912
# [232]	train-mlogloss:0.01215	valid-mlogloss:0.08913
# [233]	train-mlogloss:0.01214	valid-mlogloss:0.08916
# [234]	train-mlogloss:0.01214	valid-mlogloss:0.08916
# [235]	train-mlogloss:0.01213	valid-mlogloss:0.08917
# [236]	train-mlogloss:0.01212	valid-mlogloss:0.08917
# [237]	train-mlogloss:0.01212	valid-mlogloss:0.08919
# [238]	train-mlogloss:0.01211	valid-mlogloss:0.08921
# [239]	train-mlogloss:0.01211	valid-mlogloss:0.08923
# [240]	train-mlogloss:0.01210	valid-mlogloss:0.08924
# [241]	train-mlogloss:0.01210	valid-mlogloss:0.08924
# [242]	train-mlogloss:0.01209	valid-mlogloss:0.08925
# [243]	train-mlogloss:0.01209	valid-mlogloss:0.08925
# [244]	train-mlogloss:0.01208	valid-mlogloss:0.08925
# [245]	train-mlogloss:0.01208	valid-mlogloss:0.08928
# [246]	train-mlogloss:0.01207	valid-mlogloss:0.08928
# [247]	train-mlogloss:0.01207	valid-mlogloss:0.08929
# [248]	train-mlogloss:0.01206	valid-mlogloss:0.08930
# [checkpoint] saved /content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints/xgb_fold1_0250.json
# [249]	train-mlogloss:0.01206	valid-mlogloss:0.08931
# [250]	train-mlogloss:0.01205	valid-mlogloss:0.08932
# [251]	train-mlogloss:0.01205	valid-mlogloss:0.08933
# [252]	train-mlogloss:0.01204	valid-mlogloss:0.08933
# [253]	train-mlogloss:0.01204	valid-mlogloss:0.08933
# [254]	train-mlogloss:0.01203	valid-mlogloss:0.08934
# [255]	train-mlogloss:0.01203	valid-mlogloss:0.08936
# [256]	train-mlogloss:0.01202	valid-mlogloss:0.08938
# [257]	train-mlogloss:0.01202	valid-mlogloss:0.08939
# [258]	train-mlogloss:0.01202	valid-mlogloss:0.08940
# [259]	train-mlogloss:0.01201	valid-mlogloss:0.08940
# [260]	train-mlogloss:0.01201	valid-mlogloss:0.08941
# [261]	train-mlogloss:0.01200	valid-mlogloss:0.08941
# [262]	train-mlogloss:0.01200	valid-mlogloss:0.08943
# [263]	train-mlogloss:0.01200	valid-mlogloss:0.08945
# [264]	train-mlogloss:0.01199	valid-mlogloss:0.08945
# [265]	train-mlogloss:0.01199	valid-mlogloss:0.08946
# [266]	train-mlogloss:0.01198	valid-mlogloss:0.08948
# [267]	train-mlogloss:0.01198	valid-mlogloss:0.08948
# [268]	train-mlogloss:0.01197	valid-mlogloss:0.08950
# [269]	train-mlogloss:0.01197	valid-mlogloss:0.08950
# [270]	train-mlogloss:0.01197	valid-mlogloss:0.08950
# ✅ Saved final model: /content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints/xgb_fold1_final.json
# Fold 1 accuracy: 0.9906
# Best iteration (early stop): 170
#
# ===== Fold 2 =====
# ➡️  No checkpoint found; starting fresh.
# [0]	train-mlogloss:6.05724	valid-mlogloss:6.12935
# [1]	train-mlogloss:4.72393	valid-mlogloss:4.85141
# [2]	train-mlogloss:3.35414	valid-mlogloss:3.55833
# [3]	train-mlogloss:2.74816	valid-mlogloss:2.98365
# [4]	train-mlogloss:2.37265	valid-mlogloss:2.62658
# [5]	train-mlogloss:2.09182	valid-mlogloss:2.35977
# [6]	train-mlogloss:1.86241	valid-mlogloss:2.14056
# [7]	train-mlogloss:1.66849	valid-mlogloss:1.95374
# [8]	train-mlogloss:1.50033	valid-mlogloss:1.79039
# [9]	train-mlogloss:1.35744	valid-mlogloss:1.64995
# [10]	train-mlogloss:1.23148	valid-mlogloss:1.52531
# [11]	train-mlogloss:1.12025	valid-mlogloss:1.41442
# [12]	train-mlogloss:1.02076	valid-mlogloss:1.31472
# [13]	train-mlogloss:0.93146	valid-mlogloss:1.22491
# [14]	train-mlogloss:0.85298	valid-mlogloss:1.14540
# [15]	train-mlogloss:0.78275	valid-mlogloss:1.07326
# [16]	train-mlogloss:0.71959	valid-mlogloss:1.00752
# [17]	train-mlogloss:0.66248	valid-mlogloss:0.94768
# [18]	train-mlogloss:0.61073	valid-mlogloss:0.89284
# [19]	train-mlogloss:0.56279	valid-mlogloss:0.84152
# [20]	train-mlogloss:0.51940	valid-mlogloss:0.79438
# [21]	train-mlogloss:0.47619	valid-mlogloss:0.74736
# [22]	train-mlogloss:0.43810	valid-mlogloss:0.70515
# [23]	train-mlogloss:0.40447	valid-mlogloss:0.66701
# [24]	train-mlogloss:0.37393	valid-mlogloss:0.63192
# [25]	train-mlogloss:0.34482	valid-mlogloss:0.59818
# [26]	train-mlogloss:0.31714	valid-mlogloss:0.56550
# [27]	train-mlogloss:0.29171	valid-mlogloss:0.53514
# [28]	train-mlogloss:0.26956	valid-mlogloss:0.50793
# [29]	train-mlogloss:0.24823	valid-mlogloss:0.48170
# [30]	train-mlogloss:0.22974	valid-mlogloss:0.45801
# [31]	train-mlogloss:0.21294	valid-mlogloss:0.43619
# [32]	train-mlogloss:0.19649	valid-mlogloss:0.41484
# [33]	train-mlogloss:0.18214	valid-mlogloss:0.39550
# [34]	train-mlogloss:0.16907	valid-mlogloss:0.37742
# [35]	train-mlogloss:0.15712	valid-mlogloss:0.36056
# [36]	train-mlogloss:0.14622	valid-mlogloss:0.34479
# [37]	train-mlogloss:0.13619	valid-mlogloss:0.33001
# [38]	train-mlogloss:0.12701	valid-mlogloss:0.31625
# [39]	train-mlogloss:0.11858	valid-mlogloss:0.30318
# [40]	train-mlogloss:0.11080	valid-mlogloss:0.29102
# [41]	train-mlogloss:0.10365	valid-mlogloss:0.27967
# [42]	train-mlogloss:0.09707	valid-mlogloss:0.26887
# [43]	train-mlogloss:0.09100	valid-mlogloss:0.25874
# [44]	train-mlogloss:0.08542	valid-mlogloss:0.24917
# [45]	train-mlogloss:0.08029	valid-mlogloss:0.24016
# [46]	train-mlogloss:0.07554	valid-mlogloss:0.23171
# [47]	train-mlogloss:0.07117	valid-mlogloss:0.22376
# [48]	train-mlogloss:0.06713	valid-mlogloss:0.21626
# [49]	train-mlogloss:0.06343	valid-mlogloss:0.20922
# [50]	train-mlogloss:0.06000	valid-mlogloss:0.20264
# [51]	train-mlogloss:0.05686	valid-mlogloss:0.19640
# [52]	train-mlogloss:0.05396	valid-mlogloss:0.19064
# [53]	train-mlogloss:0.05128	valid-mlogloss:0.18521
# [54]	train-mlogloss:0.04881	valid-mlogloss:0.18007
# [55]	train-mlogloss:0.04652	valid-mlogloss:0.17530
# [56]	train-mlogloss:0.04442	valid-mlogloss:0.17083
# [57]	train-mlogloss:0.04248	valid-mlogloss:0.16652
# [58]	train-mlogloss:0.04070	valid-mlogloss:0.16262
# [59]	train-mlogloss:0.03904	valid-mlogloss:0.15889
# [60]	train-mlogloss:0.03751	valid-mlogloss:0.15544
# [61]	train-mlogloss:0.03609	valid-mlogloss:0.15220
# [62]	train-mlogloss:0.03477	valid-mlogloss:0.14916
# [63]	train-mlogloss:0.03354	valid-mlogloss:0.14625
# [64]	train-mlogloss:0.03239	valid-mlogloss:0.14352
# [65]	train-mlogloss:0.03132	valid-mlogloss:0.14090
# [66]	train-mlogloss:0.03031	valid-mlogloss:0.13847
# [67]	train-mlogloss:0.02935	valid-mlogloss:0.13608
# [68]	train-mlogloss:0.02846	valid-mlogloss:0.13381
# [69]	train-mlogloss:0.02763	valid-mlogloss:0.13166
# [70]	train-mlogloss:0.02683	valid-mlogloss:0.12966
# [71]	train-mlogloss:0.02608	valid-mlogloss:0.12768
# [72]	train-mlogloss:0.02537	valid-mlogloss:0.12578
# [73]	train-mlogloss:0.02469	valid-mlogloss:0.12402
# [74]	train-mlogloss:0.02404	valid-mlogloss:0.12229
# [75]	train-mlogloss:0.02342	valid-mlogloss:0.12057
# [76]	train-mlogloss:0.02284	valid-mlogloss:0.11898
# [77]	train-mlogloss:0.02229	valid-mlogloss:0.11747
# [78]	train-mlogloss:0.02177	valid-mlogloss:0.11603
# [79]	train-mlogloss:0.02127	valid-mlogloss:0.11465
# [80]	train-mlogloss:0.02080	valid-mlogloss:0.11330
# [81]	train-mlogloss:0.02036	valid-mlogloss:0.11203
# [82]	train-mlogloss:0.01993	valid-mlogloss:0.11081
# [83]	train-mlogloss:0.01953	valid-mlogloss:0.10968
# [84]	train-mlogloss:0.01915	valid-mlogloss:0.10858
# [85]	train-mlogloss:0.01879	valid-mlogloss:0.10751
# [86]	train-mlogloss:0.01845	valid-mlogloss:0.10652
# [87]	train-mlogloss:0.01812	valid-mlogloss:0.10558
# [88]	train-mlogloss:0.01782	valid-mlogloss:0.10467
# [89]	train-mlogloss:0.01754	valid-mlogloss:0.10384
# [90]	train-mlogloss:0.01726	valid-mlogloss:0.10304
# [91]	train-mlogloss:0.01701	valid-mlogloss:0.10229
# [92]	train-mlogloss:0.01678	valid-mlogloss:0.10157
# [93]	train-mlogloss:0.01655	valid-mlogloss:0.10091
# [94]	train-mlogloss:0.01635	valid-mlogloss:0.10030
# [95]	train-mlogloss:0.01615	valid-mlogloss:0.09971
# [96]	train-mlogloss:0.01596	valid-mlogloss:0.09917
# [97]	train-mlogloss:0.01579	valid-mlogloss:0.09866
# [98]	train-mlogloss:0.01562	valid-mlogloss:0.09821
# [99]	train-mlogloss:0.01547	valid-mlogloss:0.09777
# [100]	train-mlogloss:0.01532	valid-mlogloss:0.09738
# [101]	train-mlogloss:0.01519	valid-mlogloss:0.09700
# [102]	train-mlogloss:0.01506	valid-mlogloss:0.09665
# [103]	train-mlogloss:0.01494	valid-mlogloss:0.09632
# [104]	train-mlogloss:0.01483	valid-mlogloss:0.09598
# [105]	train-mlogloss:0.01472	valid-mlogloss:0.09566
# [106]	train-mlogloss:0.01462	valid-mlogloss:0.09541
# [107]	train-mlogloss:0.01453	valid-mlogloss:0.09518
# [108]	train-mlogloss:0.01443	valid-mlogloss:0.09495
# [109]	train-mlogloss:0.01435	valid-mlogloss:0.09473
# [110]	train-mlogloss:0.01426	valid-mlogloss:0.09452
# [111]	train-mlogloss:0.01419	valid-mlogloss:0.09433
# [112]	train-mlogloss:0.01412	valid-mlogloss:0.09416
# [113]	train-mlogloss:0.01405	valid-mlogloss:0.09399
# [114]	train-mlogloss:0.01398	valid-mlogloss:0.09384
# [115]	train-mlogloss:0.01392	valid-mlogloss:0.09369
# [116]	train-mlogloss:0.01386	valid-mlogloss:0.09355
# [117]	train-mlogloss:0.01381	valid-mlogloss:0.09342
# [118]	train-mlogloss:0.01375	valid-mlogloss:0.09330
# [119]	train-mlogloss:0.01370	valid-mlogloss:0.09317
# [120]	train-mlogloss:0.01365	valid-mlogloss:0.09306
# [121]	train-mlogloss:0.01361	valid-mlogloss:0.09295
# [122]	train-mlogloss:0.01356	valid-mlogloss:0.09284
# [123]	train-mlogloss:0.01352	valid-mlogloss:0.09275
# [124]	train-mlogloss:0.01348	valid-mlogloss:0.09266
# [125]	train-mlogloss:0.01343	valid-mlogloss:0.09258
# [126]	train-mlogloss:0.01340	valid-mlogloss:0.09251
# [127]	train-mlogloss:0.01336	valid-mlogloss:0.09244
# [128]	train-mlogloss:0.01332	valid-mlogloss:0.09238
# [129]	train-mlogloss:0.01329	valid-mlogloss:0.09232
# [130]	train-mlogloss:0.01326	valid-mlogloss:0.09227
# [131]	train-mlogloss:0.01323	valid-mlogloss:0.09220
# [132]	train-mlogloss:0.01319	valid-mlogloss:0.09214
# [133]	train-mlogloss:0.01316	valid-mlogloss:0.09209
# [134]	train-mlogloss:0.01313	valid-mlogloss:0.09205
# [135]	train-mlogloss:0.01310	valid-mlogloss:0.09199
# [136]	train-mlogloss:0.01307	valid-mlogloss:0.09194
# [137]	train-mlogloss:0.01304	valid-mlogloss:0.09191
# [138]	train-mlogloss:0.01302	valid-mlogloss:0.09187
# [139]	train-mlogloss:0.01299	valid-mlogloss:0.09184
# [140]	train-mlogloss:0.01297	valid-mlogloss:0.09180
# [141]	train-mlogloss:0.01294	valid-mlogloss:0.09175
# [142]	train-mlogloss:0.01292	valid-mlogloss:0.09171
# [143]	train-mlogloss:0.01290	valid-mlogloss:0.09168
# [144]	train-mlogloss:0.01287	valid-mlogloss:0.09165
# [145]	train-mlogloss:0.01285	valid-mlogloss:0.09163
# [146]	train-mlogloss:0.01283	valid-mlogloss:0.09159
# [147]	train-mlogloss:0.01281	valid-mlogloss:0.09157
# [148]	train-mlogloss:0.01279	valid-mlogloss:0.09155
# [149]	train-mlogloss:0.01277	valid-mlogloss:0.09154
# [150]	train-mlogloss:0.01276	valid-mlogloss:0.09151
# [151]	train-mlogloss:0.01274	valid-mlogloss:0.09148
# [152]	train-mlogloss:0.01272	valid-mlogloss:0.09146
# [153]	train-mlogloss:0.01270	valid-mlogloss:0.09145
# [154]	train-mlogloss:0.01269	valid-mlogloss:0.09144
# [155]	train-mlogloss:0.01267	valid-mlogloss:0.09144
# [156]	train-mlogloss:0.01265	valid-mlogloss:0.09142
# [157]	train-mlogloss:0.01264	valid-mlogloss:0.09141
# [158]	train-mlogloss:0.01262	valid-mlogloss:0.09140
# [159]	train-mlogloss:0.01260	valid-mlogloss:0.09139
# [160]	train-mlogloss:0.01259	valid-mlogloss:0.09137
# [161]	train-mlogloss:0.01258	valid-mlogloss:0.09136
# [162]	train-mlogloss:0.01256	valid-mlogloss:0.09135
# [163]	train-mlogloss:0.01255	valid-mlogloss:0.09136
# [164]	train-mlogloss:0.01253	valid-mlogloss:0.09137
# [165]	train-mlogloss:0.01252	valid-mlogloss:0.09135
# [166]	train-mlogloss:0.01250	valid-mlogloss:0.09134
# [167]	train-mlogloss:0.01249	valid-mlogloss:0.09135
# [168]	train-mlogloss:0.01248	valid-mlogloss:0.09136
# [169]	train-mlogloss:0.01247	valid-mlogloss:0.09135
# [170]	train-mlogloss:0.01245	valid-mlogloss:0.09135
# [171]	train-mlogloss:0.01244	valid-mlogloss:0.09134
# [172]	train-mlogloss:0.01243	valid-mlogloss:0.09132
# [173]	train-mlogloss:0.01242	valid-mlogloss:0.09131
# [174]	train-mlogloss:0.01240	valid-mlogloss:0.09130
# [175]	train-mlogloss:0.01239	valid-mlogloss:0.09130
# [176]	train-mlogloss:0.01238	valid-mlogloss:0.09129
# [177]	train-mlogloss:0.01237	valid-mlogloss:0.09130
# [178]	train-mlogloss:0.01236	valid-mlogloss:0.09129
# [179]	train-mlogloss:0.01235	valid-mlogloss:0.09128
# [180]	train-mlogloss:0.01234	valid-mlogloss:0.09129
# [181]	train-mlogloss:0.01233	valid-mlogloss:0.09128
# [182]	train-mlogloss:0.01232	valid-mlogloss:0.09128
# [183]	train-mlogloss:0.01231	valid-mlogloss:0.09128
# [184]	train-mlogloss:0.01230	valid-mlogloss:0.09130
# [185]	train-mlogloss:0.01229	valid-mlogloss:0.09131
# [186]	train-mlogloss:0.01228	valid-mlogloss:0.09132
# [187]	train-mlogloss:0.01227	valid-mlogloss:0.09132
# [188]	train-mlogloss:0.01226	valid-mlogloss:0.09132
# [189]	train-mlogloss:0.01225	valid-mlogloss:0.09131
# [190]	train-mlogloss:0.01224	valid-mlogloss:0.09131
# [191]	train-mlogloss:0.01223	valid-mlogloss:0.09131
# [192]	train-mlogloss:0.01222	valid-mlogloss:0.09131
# [193]	train-mlogloss:0.01222	valid-mlogloss:0.09132
# [194]	train-mlogloss:0.01221	valid-mlogloss:0.09133
# [195]	train-mlogloss:0.01220	valid-mlogloss:0.09134
# [196]	train-mlogloss:0.01219	valid-mlogloss:0.09135
# [197]	train-mlogloss:0.01218	valid-mlogloss:0.09134
# [198]	train-mlogloss:0.01217	valid-mlogloss:0.09135
# [199]	train-mlogloss:0.01216	valid-mlogloss:0.09135
# [200]	train-mlogloss:0.01216	valid-mlogloss:0.09136
# [201]	train-mlogloss:0.01215	valid-mlogloss:0.09136
# [202]	train-mlogloss:0.01214	valid-mlogloss:0.09137
# [203]	train-mlogloss:0.01213	valid-mlogloss:0.09138
# [204]	train-mlogloss:0.01213	valid-mlogloss:0.09139
# [205]	train-mlogloss:0.01212	valid-mlogloss:0.09141
# [206]	train-mlogloss:0.01211	valid-mlogloss:0.09142
# [207]	train-mlogloss:0.01210	valid-mlogloss:0.09143
# [208]	train-mlogloss:0.01210	valid-mlogloss:0.09144
# [209]	train-mlogloss:0.01209	valid-mlogloss:0.09145
# [210]	train-mlogloss:0.01208	valid-mlogloss:0.09146
# [211]	train-mlogloss:0.01207	valid-mlogloss:0.09148
# [212]	train-mlogloss:0.01207	valid-mlogloss:0.09147
# [213]	train-mlogloss:0.01206	valid-mlogloss:0.09148
# [214]	train-mlogloss:0.01205	valid-mlogloss:0.09149
# [215]	train-mlogloss:0.01205	valid-mlogloss:0.09150
# [216]	train-mlogloss:0.01204	valid-mlogloss:0.09151
# [217]	train-mlogloss:0.01203	valid-mlogloss:0.09152
# [218]	train-mlogloss:0.01203	valid-mlogloss:0.09153
# [219]	train-mlogloss:0.01202	valid-mlogloss:0.09153
# [220]	train-mlogloss:0.01201	valid-mlogloss:0.09155
# [221]	train-mlogloss:0.01201	valid-mlogloss:0.09155
# [222]	train-mlogloss:0.01200	valid-mlogloss:0.09155
# [223]	train-mlogloss:0.01199	valid-mlogloss:0.09155
# [224]	train-mlogloss:0.01199	valid-mlogloss:0.09155
# [225]	train-mlogloss:0.01198	valid-mlogloss:0.09157
# [226]	train-mlogloss:0.01198	valid-mlogloss:0.09157
# [227]	train-mlogloss:0.01197	valid-mlogloss:0.09158
# [228]	train-mlogloss:0.01196	valid-mlogloss:0.09158
# [229]	train-mlogloss:0.01196	valid-mlogloss:0.09160
# [230]	train-mlogloss:0.01195	valid-mlogloss:0.09162
# [231]	train-mlogloss:0.01195	valid-mlogloss:0.09164
# [232]	train-mlogloss:0.01194	valid-mlogloss:0.09165
# [233]	train-mlogloss:0.01193	valid-mlogloss:0.09166
# [234]	train-mlogloss:0.01193	valid-mlogloss:0.09167
# [235]	train-mlogloss:0.01192	valid-mlogloss:0.09168
# [236]	train-mlogloss:0.01192	valid-mlogloss:0.09169
# [237]	train-mlogloss:0.01191	valid-mlogloss:0.09169
# [238]	train-mlogloss:0.01191	valid-mlogloss:0.09170
# [239]	train-mlogloss:0.01190	valid-mlogloss:0.09171
# [240]	train-mlogloss:0.01189	valid-mlogloss:0.09171
# [241]	train-mlogloss:0.01189	valid-mlogloss:0.09173
# [242]	train-mlogloss:0.01188	valid-mlogloss:0.09174
# [243]	train-mlogloss:0.01188	valid-mlogloss:0.09175
# [244]	train-mlogloss:0.01187	valid-mlogloss:0.09178
# [245]	train-mlogloss:0.01187	valid-mlogloss:0.09180
# [246]	train-mlogloss:0.01186	valid-mlogloss:0.09181
# [247]	train-mlogloss:0.01186	valid-mlogloss:0.09182
# [248]	train-mlogloss:0.01186	valid-mlogloss:0.09183
# [checkpoint] saved /content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints/xgb_fold2_0250.json
# [249]	train-mlogloss:0.01185	valid-mlogloss:0.09185
# [250]	train-mlogloss:0.01185	valid-mlogloss:0.09185
# [251]	train-mlogloss:0.01184	valid-mlogloss:0.09187
# [252]	train-mlogloss:0.01184	valid-mlogloss:0.09188
# [253]	train-mlogloss:0.01183	valid-mlogloss:0.09189
# [254]	train-mlogloss:0.01183	valid-mlogloss:0.09190
# [255]	train-mlogloss:0.01182	valid-mlogloss:0.09190
# [256]	train-mlogloss:0.01182	valid-mlogloss:0.09192
# [257]	train-mlogloss:0.01181	valid-mlogloss:0.09194
# [258]	train-mlogloss:0.01181	valid-mlogloss:0.09194
# [259]	train-mlogloss:0.01180	valid-mlogloss:0.09193
# [260]	train-mlogloss:0.01180	valid-mlogloss:0.09194
# [261]	train-mlogloss:0.01179	valid-mlogloss:0.09194
# [262]	train-mlogloss:0.01179	valid-mlogloss:0.09196
# [263]	train-mlogloss:0.01179	valid-mlogloss:0.09198
# [264]	train-mlogloss:0.01178	valid-mlogloss:0.09197
# [265]	train-mlogloss:0.01178	valid-mlogloss:0.09198
# [266]	train-mlogloss:0.01177	valid-mlogloss:0.09199
# [267]	train-mlogloss:0.01177	valid-mlogloss:0.09198
# [268]	train-mlogloss:0.01177	valid-mlogloss:0.09199
# [269]	train-mlogloss:0.01176	valid-mlogloss:0.09201
# [270]	train-mlogloss:0.01176	valid-mlogloss:0.09202
# [271]	train-mlogloss:0.01175	valid-mlogloss:0.09202
# [272]	train-mlogloss:0.01175	valid-mlogloss:0.09203
# [273]	train-mlogloss:0.01175	valid-mlogloss:0.09203
# [274]	train-mlogloss:0.01174	valid-mlogloss:0.09205
# [275]	train-mlogloss:0.01174	valid-mlogloss:0.09206
# [276]	train-mlogloss:0.01173	valid-mlogloss:0.09206
# [277]	train-mlogloss:0.01173	valid-mlogloss:0.09207
# [278]	train-mlogloss:0.01173	valid-mlogloss:0.09207
# [279]	train-mlogloss:0.01172	valid-mlogloss:0.09207
# [280]	train-mlogloss:0.01172	valid-mlogloss:0.09207
# [281]	train-mlogloss:0.01172	valid-mlogloss:0.09208
# ✅ Saved final model: /content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints/xgb_fold2_final.json
# Fold 2 accuracy: 0.9904
# Best iteration (early stop): 181
#
# ===== Fold 3 =====
# ➡️  No checkpoint found; starting fresh.
# [0]	train-mlogloss:6.05712	valid-mlogloss:6.12241
# [1]	train-mlogloss:4.72791	valid-mlogloss:4.84647
# [2]	train-mlogloss:3.36064	valid-mlogloss:3.57162
# [3]	train-mlogloss:2.74739	valid-mlogloss:2.99136
# [4]	train-mlogloss:2.37409	valid-mlogloss:2.63764
# [5]	train-mlogloss:2.09302	valid-mlogloss:2.37109
# [6]	train-mlogloss:1.86323	valid-mlogloss:2.15188
# [7]	train-mlogloss:1.66849	valid-mlogloss:1.96445
# [8]	train-mlogloss:1.50014	valid-mlogloss:1.80104
# [9]	train-mlogloss:1.35760	valid-mlogloss:1.66137
# [10]	train-mlogloss:1.23159	valid-mlogloss:1.53701
# [11]	train-mlogloss:1.12000	valid-mlogloss:1.42614
# [12]	train-mlogloss:1.02064	valid-mlogloss:1.32678
# [13]	train-mlogloss:0.93289	valid-mlogloss:1.23785
# [14]	train-mlogloss:0.85485	valid-mlogloss:1.15810
# [15]	train-mlogloss:0.78491	valid-mlogloss:1.08616
# [16]	train-mlogloss:0.72177	valid-mlogloss:1.02000
# [17]	train-mlogloss:0.66481	valid-mlogloss:0.96020
# [18]	train-mlogloss:0.61210	valid-mlogloss:0.90384
# [19]	train-mlogloss:0.56268	valid-mlogloss:0.85052
# [20]	train-mlogloss:0.51820	valid-mlogloss:0.80220
# [21]	train-mlogloss:0.47753	valid-mlogloss:0.75708
# [22]	train-mlogloss:0.44101	valid-mlogloss:0.71602
# [23]	train-mlogloss:0.40584	valid-mlogloss:0.67615
# [24]	train-mlogloss:0.37366	valid-mlogloss:0.63935
# [25]	train-mlogloss:0.34336	valid-mlogloss:0.60349
# [26]	train-mlogloss:0.31657	valid-mlogloss:0.57169
# [27]	train-mlogloss:0.29270	valid-mlogloss:0.54265
# [28]	train-mlogloss:0.27008	valid-mlogloss:0.51472
# [29]	train-mlogloss:0.24863	valid-mlogloss:0.48782
# [30]	train-mlogloss:0.23006	valid-mlogloss:0.46407
# [31]	train-mlogloss:0.21316	valid-mlogloss:0.44190
# [32]	train-mlogloss:0.19772	valid-mlogloss:0.42121
# [33]	train-mlogloss:0.18267	valid-mlogloss:0.40091
# [34]	train-mlogloss:0.16941	valid-mlogloss:0.38248
# [35]	train-mlogloss:0.15738	valid-mlogloss:0.36552
# [36]	train-mlogloss:0.14640	valid-mlogloss:0.34959
# [37]	train-mlogloss:0.13630	valid-mlogloss:0.33467
# [38]	train-mlogloss:0.12708	valid-mlogloss:0.32061
# [39]	train-mlogloss:0.11862	valid-mlogloss:0.30759
# [40]	train-mlogloss:0.11084	valid-mlogloss:0.29524
# [41]	train-mlogloss:0.10368	valid-mlogloss:0.28370
# [42]	train-mlogloss:0.09708	valid-mlogloss:0.27288
# [43]	train-mlogloss:0.09101	valid-mlogloss:0.26265
# [44]	train-mlogloss:0.08543	valid-mlogloss:0.25293
# [45]	train-mlogloss:0.08029	valid-mlogloss:0.24381
# [46]	train-mlogloss:0.07553	valid-mlogloss:0.23529
# [47]	train-mlogloss:0.07115	valid-mlogloss:0.22717
# [48]	train-mlogloss:0.06711	valid-mlogloss:0.21963
# [49]	train-mlogloss:0.06340	valid-mlogloss:0.21244
# [50]	train-mlogloss:0.05997	valid-mlogloss:0.20560
# [51]	train-mlogloss:0.05682	valid-mlogloss:0.19922
# [52]	train-mlogloss:0.05391	valid-mlogloss:0.19330
# [53]	train-mlogloss:0.05126	valid-mlogloss:0.18777
# [54]	train-mlogloss:0.04881	valid-mlogloss:0.18261
# [55]	train-mlogloss:0.04653	valid-mlogloss:0.17778
# [56]	train-mlogloss:0.04443	valid-mlogloss:0.17329
# [57]	train-mlogloss:0.04250	valid-mlogloss:0.16905
# [58]	train-mlogloss:0.04072	valid-mlogloss:0.16510
# [59]	train-mlogloss:0.03908	valid-mlogloss:0.16128
# [60]	train-mlogloss:0.03755	valid-mlogloss:0.15776
# [61]	train-mlogloss:0.03614	valid-mlogloss:0.15444
# [62]	train-mlogloss:0.03482	valid-mlogloss:0.15135
# [63]	train-mlogloss:0.03359	valid-mlogloss:0.14836
# [64]	train-mlogloss:0.03245	valid-mlogloss:0.14558
# [65]	train-mlogloss:0.03137	valid-mlogloss:0.14295
# [66]	train-mlogloss:0.03037	valid-mlogloss:0.14041
# [67]	train-mlogloss:0.02942	valid-mlogloss:0.13807
# [68]	train-mlogloss:0.02853	valid-mlogloss:0.13574
# [69]	train-mlogloss:0.02769	valid-mlogloss:0.13359
# [70]	train-mlogloss:0.02690	valid-mlogloss:0.13153
# [71]	train-mlogloss:0.02615	valid-mlogloss:0.12954
# [72]	train-mlogloss:0.02544	valid-mlogloss:0.12764
# [73]	train-mlogloss:0.02476	valid-mlogloss:0.12577
# [74]	train-mlogloss:0.02412	valid-mlogloss:0.12399
# [75]	train-mlogloss:0.02352	valid-mlogloss:0.12226
# [76]	train-mlogloss:0.02294	valid-mlogloss:0.12064
# [77]	train-mlogloss:0.02239	valid-mlogloss:0.11904
# [78]	train-mlogloss:0.02188	valid-mlogloss:0.11756
# [79]	train-mlogloss:0.02138	valid-mlogloss:0.11613
# [80]	train-mlogloss:0.02091	valid-mlogloss:0.11475
# [81]	train-mlogloss:0.02047	valid-mlogloss:0.11345
# [82]	train-mlogloss:0.02004	valid-mlogloss:0.11218
# [83]	train-mlogloss:0.01964	valid-mlogloss:0.11099
# [84]	train-mlogloss:0.01927	valid-mlogloss:0.10986
# [85]	train-mlogloss:0.01891	valid-mlogloss:0.10875
# [86]	train-mlogloss:0.01857	valid-mlogloss:0.10772
# [87]	train-mlogloss:0.01826	valid-mlogloss:0.10672
# [88]	train-mlogloss:0.01796	valid-mlogloss:0.10577
# [89]	train-mlogloss:0.01768	valid-mlogloss:0.10490
# [90]	train-mlogloss:0.01741	valid-mlogloss:0.10410
# [91]	train-mlogloss:0.01716	valid-mlogloss:0.10335
# [92]	train-mlogloss:0.01693	valid-mlogloss:0.10262
# [93]	train-mlogloss:0.01670	valid-mlogloss:0.10193
# [94]	train-mlogloss:0.01649	valid-mlogloss:0.10128
# [95]	train-mlogloss:0.01630	valid-mlogloss:0.10068
# [96]	train-mlogloss:0.01611	valid-mlogloss:0.10015
# [97]	train-mlogloss:0.01593	valid-mlogloss:0.09960
# [98]	train-mlogloss:0.01577	valid-mlogloss:0.09914
# [99]	train-mlogloss:0.01562	valid-mlogloss:0.09869
# [100]	train-mlogloss:0.01548	valid-mlogloss:0.09824
# [101]	train-mlogloss:0.01534	valid-mlogloss:0.09787
# [102]	train-mlogloss:0.01521	valid-mlogloss:0.09751
# [103]	train-mlogloss:0.01509	valid-mlogloss:0.09716
# [104]	train-mlogloss:0.01498	valid-mlogloss:0.09684
# [105]	train-mlogloss:0.01487	valid-mlogloss:0.09654
# [106]	train-mlogloss:0.01477	valid-mlogloss:0.09626
# [107]	train-mlogloss:0.01468	valid-mlogloss:0.09597
# [108]	train-mlogloss:0.01458	valid-mlogloss:0.09574
# [109]	train-mlogloss:0.01450	valid-mlogloss:0.09550
# [110]	train-mlogloss:0.01442	valid-mlogloss:0.09528
# [111]	train-mlogloss:0.01434	valid-mlogloss:0.09508
# [112]	train-mlogloss:0.01427	valid-mlogloss:0.09488
# [113]	train-mlogloss:0.01420	valid-mlogloss:0.09472
# [114]	train-mlogloss:0.01414	valid-mlogloss:0.09456
# [115]	train-mlogloss:0.01408	valid-mlogloss:0.09439
# [116]	train-mlogloss:0.01402	valid-mlogloss:0.09425
# [117]	train-mlogloss:0.01396	valid-mlogloss:0.09411
# [118]	train-mlogloss:0.01391	valid-mlogloss:0.09398
# [119]	train-mlogloss:0.01386	valid-mlogloss:0.09384
# [120]	train-mlogloss:0.01381	valid-mlogloss:0.09373
# [121]	train-mlogloss:0.01376	valid-mlogloss:0.09360
# [122]	train-mlogloss:0.01372	valid-mlogloss:0.09349
# [123]	train-mlogloss:0.01367	valid-mlogloss:0.09338
# [124]	train-mlogloss:0.01363	valid-mlogloss:0.09328
# [125]	train-mlogloss:0.01360	valid-mlogloss:0.09321
# [126]	train-mlogloss:0.01356	valid-mlogloss:0.09316
# [127]	train-mlogloss:0.01352	valid-mlogloss:0.09310
# [128]	train-mlogloss:0.01348	valid-mlogloss:0.09301
# [129]	train-mlogloss:0.01345	valid-mlogloss:0.09295
# [130]	train-mlogloss:0.01342	valid-mlogloss:0.09290
# [131]	train-mlogloss:0.01339	valid-mlogloss:0.09284
# [132]	train-mlogloss:0.01336	valid-mlogloss:0.09278
# [133]	train-mlogloss:0.01333	valid-mlogloss:0.09272
# [134]	train-mlogloss:0.01330	valid-mlogloss:0.09267
# [135]	train-mlogloss:0.01327	valid-mlogloss:0.09262
# [136]	train-mlogloss:0.01325	valid-mlogloss:0.09259
# [137]	train-mlogloss:0.01322	valid-mlogloss:0.09255
# [138]	train-mlogloss:0.01320	valid-mlogloss:0.09252
# [139]	train-mlogloss:0.01317	valid-mlogloss:0.09250
# [140]	train-mlogloss:0.01315	valid-mlogloss:0.09247
# [141]	train-mlogloss:0.01313	valid-mlogloss:0.09244
# [142]	train-mlogloss:0.01310	valid-mlogloss:0.09242
# [143]	train-mlogloss:0.01308	valid-mlogloss:0.09238
# [144]	train-mlogloss:0.01306	valid-mlogloss:0.09236
# [145]	train-mlogloss:0.01304	valid-mlogloss:0.09235
# [146]	train-mlogloss:0.01302	valid-mlogloss:0.09232
# [147]	train-mlogloss:0.01300	valid-mlogloss:0.09229
# [148]	train-mlogloss:0.01298	valid-mlogloss:0.09227
# [149]	train-mlogloss:0.01296	valid-mlogloss:0.09224
# [150]	train-mlogloss:0.01295	valid-mlogloss:0.09223
# [151]	train-mlogloss:0.01293	valid-mlogloss:0.09221
# [152]	train-mlogloss:0.01291	valid-mlogloss:0.09221
# [153]	train-mlogloss:0.01289	valid-mlogloss:0.09219
# [154]	train-mlogloss:0.01287	valid-mlogloss:0.09218
# [155]	train-mlogloss:0.01286	valid-mlogloss:0.09216
# [156]	train-mlogloss:0.01284	valid-mlogloss:0.09215
# [157]	train-mlogloss:0.01283	valid-mlogloss:0.09213
# [158]	train-mlogloss:0.01281	valid-mlogloss:0.09213
# [159]	train-mlogloss:0.01280	valid-mlogloss:0.09213
# [160]	train-mlogloss:0.01278	valid-mlogloss:0.09210
# [161]	train-mlogloss:0.01277	valid-mlogloss:0.09209
# [162]	train-mlogloss:0.01275	valid-mlogloss:0.09208
# [163]	train-mlogloss:0.01274	valid-mlogloss:0.09207
# [164]	train-mlogloss:0.01272	valid-mlogloss:0.09206
# [165]	train-mlogloss:0.01271	valid-mlogloss:0.09206
# [166]	train-mlogloss:0.01270	valid-mlogloss:0.09206
# [167]	train-mlogloss:0.01268	valid-mlogloss:0.09206
# [168]	train-mlogloss:0.01267	valid-mlogloss:0.09206
# [169]	train-mlogloss:0.01266	valid-mlogloss:0.09206
# [170]	train-mlogloss:0.01265	valid-mlogloss:0.09207
# [171]	train-mlogloss:0.01264	valid-mlogloss:0.09208
# [172]	train-mlogloss:0.01262	valid-mlogloss:0.09207
# [173]	train-mlogloss:0.01261	valid-mlogloss:0.09208
# [174]	train-mlogloss:0.01260	valid-mlogloss:0.09207
# [175]	train-mlogloss:0.01259	valid-mlogloss:0.09209
# [176]	train-mlogloss:0.01258	valid-mlogloss:0.09210
# [177]	train-mlogloss:0.01257	valid-mlogloss:0.09210
# [178]	train-mlogloss:0.01256	valid-mlogloss:0.09209
# [179]	train-mlogloss:0.01255	valid-mlogloss:0.09210
# [180]	train-mlogloss:0.01254	valid-mlogloss:0.09207
# [181]	train-mlogloss:0.01253	valid-mlogloss:0.09207
# [182]	train-mlogloss:0.01252	valid-mlogloss:0.09207
# [183]	train-mlogloss:0.01251	valid-mlogloss:0.09207
# [184]	train-mlogloss:0.01250	valid-mlogloss:0.09206
# [185]	train-mlogloss:0.01249	valid-mlogloss:0.09206
# [186]	train-mlogloss:0.01248	valid-mlogloss:0.09206
# [187]	train-mlogloss:0.01247	valid-mlogloss:0.09206
# [188]	train-mlogloss:0.01246	valid-mlogloss:0.09204
# [189]	train-mlogloss:0.01245	valid-mlogloss:0.09203
# [190]	train-mlogloss:0.01244	valid-mlogloss:0.09203
# [191]	train-mlogloss:0.01243	valid-mlogloss:0.09202
# [192]	train-mlogloss:0.01242	valid-mlogloss:0.09201
# [193]	train-mlogloss:0.01241	valid-mlogloss:0.09201
# [194]	train-mlogloss:0.01241	valid-mlogloss:0.09203
# [195]	train-mlogloss:0.01240	valid-mlogloss:0.09202
# [196]	train-mlogloss:0.01239	valid-mlogloss:0.09203
# [197]	train-mlogloss:0.01238	valid-mlogloss:0.09203
# [198]	train-mlogloss:0.01237	valid-mlogloss:0.09203
# [199]	train-mlogloss:0.01237	valid-mlogloss:0.09203
# [200]	train-mlogloss:0.01236	valid-mlogloss:0.09202
# [201]	train-mlogloss:0.01235	valid-mlogloss:0.09204
# [202]	train-mlogloss:0.01234	valid-mlogloss:0.09206
# [203]	train-mlogloss:0.01233	valid-mlogloss:0.09207
# [204]	train-mlogloss:0.01232	valid-mlogloss:0.09208
# [205]	train-mlogloss:0.01232	valid-mlogloss:0.09208
# [206]	train-mlogloss:0.01231	valid-mlogloss:0.09209
# [207]	train-mlogloss:0.01230	valid-mlogloss:0.09208
# [208]	train-mlogloss:0.01229	valid-mlogloss:0.09209
# [209]	train-mlogloss:0.01229	valid-mlogloss:0.09210
# [210]	train-mlogloss:0.01228	valid-mlogloss:0.09210
# [211]	train-mlogloss:0.01227	valid-mlogloss:0.09212
# [212]	train-mlogloss:0.01227	valid-mlogloss:0.09213
# [213]	train-mlogloss:0.01226	valid-mlogloss:0.09213
# [214]	train-mlogloss:0.01225	valid-mlogloss:0.09214
# [215]	train-mlogloss:0.01225	valid-mlogloss:0.09214
# [216]	train-mlogloss:0.01224	valid-mlogloss:0.09215
# [217]	train-mlogloss:0.01223	valid-mlogloss:0.09214
# [218]	train-mlogloss:0.01223	valid-mlogloss:0.09215
# [219]	train-mlogloss:0.01222	valid-mlogloss:0.09216
# [220]	train-mlogloss:0.01221	valid-mlogloss:0.09217
# [221]	train-mlogloss:0.01221	valid-mlogloss:0.09218
# [222]	train-mlogloss:0.01220	valid-mlogloss:0.09217
# [223]	train-mlogloss:0.01219	valid-mlogloss:0.09218
# [224]	train-mlogloss:0.01219	valid-mlogloss:0.09218
# [225]	train-mlogloss:0.01218	valid-mlogloss:0.09218
# [226]	train-mlogloss:0.01218	valid-mlogloss:0.09219
# [227]	train-mlogloss:0.01217	valid-mlogloss:0.09218
# [228]	train-mlogloss:0.01217	valid-mlogloss:0.09219
# [229]	train-mlogloss:0.01216	valid-mlogloss:0.09218
# [230]	train-mlogloss:0.01215	valid-mlogloss:0.09219
# [231]	train-mlogloss:0.01215	valid-mlogloss:0.09219
# [232]	train-mlogloss:0.01214	valid-mlogloss:0.09219
# [233]	train-mlogloss:0.01213	valid-mlogloss:0.09220
# [234]	train-mlogloss:0.01213	valid-mlogloss:0.09223
# [235]	train-mlogloss:0.01212	valid-mlogloss:0.09224
# [236]	train-mlogloss:0.01212	valid-mlogloss:0.09225
# [237]	train-mlogloss:0.01211	valid-mlogloss:0.09225
# [238]	train-mlogloss:0.01211	valid-mlogloss:0.09227
# [239]	train-mlogloss:0.01210	valid-mlogloss:0.09227
# [240]	train-mlogloss:0.01210	valid-mlogloss:0.09228
# [241]	train-mlogloss:0.01209	valid-mlogloss:0.09229
# [242]	train-mlogloss:0.01209	valid-mlogloss:0.09229
# [243]	train-mlogloss:0.01208	valid-mlogloss:0.09230
# [244]	train-mlogloss:0.01208	valid-mlogloss:0.09229
# [245]	train-mlogloss:0.01207	valid-mlogloss:0.09231
# [246]	train-mlogloss:0.01207	valid-mlogloss:0.09232
# [247]	train-mlogloss:0.01206	valid-mlogloss:0.09232
# [248]	train-mlogloss:0.01206	valid-mlogloss:0.09232
# [checkpoint] saved /content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints/xgb_fold3_0250.json
# [249]	train-mlogloss:0.01205	valid-mlogloss:0.09234
# [250]	train-mlogloss:0.01205	valid-mlogloss:0.09234
# [251]	train-mlogloss:0.01204	valid-mlogloss:0.09235
# [252]	train-mlogloss:0.01204	valid-mlogloss:0.09235
# [253]	train-mlogloss:0.01203	valid-mlogloss:0.09236
# [254]	train-mlogloss:0.01203	valid-mlogloss:0.09237
# [255]	train-mlogloss:0.01202	valid-mlogloss:0.09238
# [256]	train-mlogloss:0.01202	valid-mlogloss:0.09239
# [257]	train-mlogloss:0.01201	valid-mlogloss:0.09238
# [258]	train-mlogloss:0.01201	valid-mlogloss:0.09238
# [259]	train-mlogloss:0.01200	valid-mlogloss:0.09238
# [260]	train-mlogloss:0.01200	valid-mlogloss:0.09238
# [261]	train-mlogloss:0.01200	valid-mlogloss:0.09239
# [262]	train-mlogloss:0.01199	valid-mlogloss:0.09239
# [263]	train-mlogloss:0.01199	valid-mlogloss:0.09240
# [264]	train-mlogloss:0.01198	valid-mlogloss:0.09241
# [265]	train-mlogloss:0.01198	valid-mlogloss:0.09243
# [266]	train-mlogloss:0.01198	valid-mlogloss:0.09244
# [267]	train-mlogloss:0.01197	valid-mlogloss:0.09244
# [268]	train-mlogloss:0.01197	valid-mlogloss:0.09246
# [269]	train-mlogloss:0.01196	valid-mlogloss:0.09247
# [270]	train-mlogloss:0.01196	valid-mlogloss:0.09249
# [271]	train-mlogloss:0.01195	valid-mlogloss:0.09249
# [272]	train-mlogloss:0.01195	valid-mlogloss:0.09250
# [273]	train-mlogloss:0.01195	valid-mlogloss:0.09251
# [274]	train-mlogloss:0.01194	valid-mlogloss:0.09251
# [275]	train-mlogloss:0.01194	valid-mlogloss:0.09252
# [276]	train-mlogloss:0.01194	valid-mlogloss:0.09251
# [277]	train-mlogloss:0.01193	valid-mlogloss:0.09252
# [278]	train-mlogloss:0.01193	valid-mlogloss:0.09252
# [279]	train-mlogloss:0.01192	valid-mlogloss:0.09253
# [280]	train-mlogloss:0.01192	valid-mlogloss:0.09254
# [281]	train-mlogloss:0.01192	valid-mlogloss:0.09255
# [282]	train-mlogloss:0.01191	valid-mlogloss:0.09256
# [283]	train-mlogloss:0.01191	valid-mlogloss:0.09256
# [284]	train-mlogloss:0.01191	valid-mlogloss:0.09257
# [285]	train-mlogloss:0.01190	valid-mlogloss:0.09257
# [286]	train-mlogloss:0.01190	valid-mlogloss:0.09258
# [287]	train-mlogloss:0.01189	valid-mlogloss:0.09260
# [288]	train-mlogloss:0.01189	valid-mlogloss:0.09260
# [289]	train-mlogloss:0.01189	valid-mlogloss:0.09262
# [290]	train-mlogloss:0.01188	valid-mlogloss:0.09264
# [291]	train-mlogloss:0.01188	valid-mlogloss:0.09263
# [292]	train-mlogloss:0.01188	valid-mlogloss:0.09264
# [293]	train-mlogloss:0.01187	valid-mlogloss:0.09265
# ✅ Saved final model: /content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints/xgb_fold3_final.json
# Fold 3 accuracy: 0.9897
# Best iteration (early stop): 193
#
# ===== Fold 4 =====
# ➡️  No checkpoint found; starting fresh.
# [0]	train-mlogloss:6.05900	valid-mlogloss:6.11989
# [1]	train-mlogloss:4.73187	valid-mlogloss:4.84285
# [2]	train-mlogloss:3.36542	valid-mlogloss:3.55890
# [3]	train-mlogloss:2.75396	valid-mlogloss:2.97843
# [4]	train-mlogloss:2.37997	valid-mlogloss:2.62134
# [5]	train-mlogloss:2.09613	valid-mlogloss:2.35265
# [6]	train-mlogloss:1.86611	valid-mlogloss:2.13380
# [7]	train-mlogloss:1.67256	valid-mlogloss:1.94754
# [8]	train-mlogloss:1.50377	valid-mlogloss:1.78419
# [9]	train-mlogloss:1.35993	valid-mlogloss:1.64363
# [10]	train-mlogloss:1.23380	valid-mlogloss:1.51961
# [11]	train-mlogloss:1.12196	valid-mlogloss:1.40871
# [12]	train-mlogloss:1.02319	valid-mlogloss:1.31040
# [13]	train-mlogloss:0.93535	valid-mlogloss:1.22234
# [14]	train-mlogloss:0.85553	valid-mlogloss:1.14175
# [15]	train-mlogloss:0.78465	valid-mlogloss:1.06942
# [16]	train-mlogloss:0.72119	valid-mlogloss:1.00406
# [17]	train-mlogloss:0.66277	valid-mlogloss:0.94343
# [18]	train-mlogloss:0.61026	valid-mlogloss:0.88795
# [19]	train-mlogloss:0.56290	valid-mlogloss:0.83736
# [20]	train-mlogloss:0.51981	valid-mlogloss:0.79087
# [21]	train-mlogloss:0.47889	valid-mlogloss:0.74579
# [22]	train-mlogloss:0.44201	valid-mlogloss:0.70467
# [23]	train-mlogloss:0.40656	valid-mlogloss:0.66522
# [24]	train-mlogloss:0.37423	valid-mlogloss:0.62819
# [25]	train-mlogloss:0.34573	valid-mlogloss:0.59505
# [26]	train-mlogloss:0.31904	valid-mlogloss:0.56381
# [27]	train-mlogloss:0.29397	valid-mlogloss:0.53406
# [28]	train-mlogloss:0.27114	valid-mlogloss:0.50611
# [29]	train-mlogloss:0.24958	valid-mlogloss:0.47947
# [30]	train-mlogloss:0.23093	valid-mlogloss:0.45566
# [31]	train-mlogloss:0.21399	valid-mlogloss:0.43362
# [32]	train-mlogloss:0.19747	valid-mlogloss:0.41220
# [33]	train-mlogloss:0.18304	valid-mlogloss:0.39296
# [34]	train-mlogloss:0.16991	valid-mlogloss:0.37502
# [35]	train-mlogloss:0.15788	valid-mlogloss:0.35810
# [36]	train-mlogloss:0.14688	valid-mlogloss:0.34239
# [37]	train-mlogloss:0.13682	valid-mlogloss:0.32767
# [38]	train-mlogloss:0.12758	valid-mlogloss:0.31381
# [39]	train-mlogloss:0.11912	valid-mlogloss:0.30100
# [40]	train-mlogloss:0.11130	valid-mlogloss:0.28871
# [41]	train-mlogloss:0.10413	valid-mlogloss:0.27737
# [42]	train-mlogloss:0.09752	valid-mlogloss:0.26661
# [43]	train-mlogloss:0.09144	valid-mlogloss:0.25645
# [44]	train-mlogloss:0.08585	valid-mlogloss:0.24694
# [45]	train-mlogloss:0.08071	valid-mlogloss:0.23802
# [46]	train-mlogloss:0.07596	valid-mlogloss:0.22965
# [47]	train-mlogloss:0.07158	valid-mlogloss:0.22182
# [48]	train-mlogloss:0.06755	valid-mlogloss:0.21438
# [49]	train-mlogloss:0.06381	valid-mlogloss:0.20721
# [50]	train-mlogloss:0.06036	valid-mlogloss:0.20045
# [51]	train-mlogloss:0.05719	valid-mlogloss:0.19427
# [52]	train-mlogloss:0.05428	valid-mlogloss:0.18838
# [53]	train-mlogloss:0.05160	valid-mlogloss:0.18294
# [54]	train-mlogloss:0.04912	valid-mlogloss:0.17780
# [55]	train-mlogloss:0.04684	valid-mlogloss:0.17295
# [56]	train-mlogloss:0.04475	valid-mlogloss:0.16844
# ...
# [288]	train-mlogloss:0.01198	valid-mlogloss:0.08815
# [289]	train-mlogloss:0.01198	valid-mlogloss:0.08814
# [290]	train-mlogloss:0.01197	valid-mlogloss:0.08813
# [291]	train-mlogloss:0.01197	valid-mlogloss:0.08814
# [292]	train-mlogloss:0.01196	valid-mlogloss:0.08814
# ✅ Saved final model: /content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints/xgb_fold4_final.json
# Fold 4 accuracy: 0.9912
# Best iteration (early stop): 192
#
# ===== Fold 5 =====
# ➡️  No checkpoint found; starting fresh.
# [0]	train-mlogloss:6.05900	valid-mlogloss:6.11936
# [1]	train-mlogloss:4.73093	valid-mlogloss:4.84831
# [2]	train-mlogloss:3.36054	valid-mlogloss:3.56649
# [3]	train-mlogloss:2.75048	valid-mlogloss:2.98484
# [4]	train-mlogloss:2.37765	valid-mlogloss:2.62949
# [5]	train-mlogloss:2.09410	valid-mlogloss:2.36122
# [6]	train-mlogloss:1.86513	valid-mlogloss:2.14239
# [7]	train-mlogloss:1.67075	valid-mlogloss:1.95496
# [8]	train-mlogloss:1.50226	valid-mlogloss:1.79121
# [9]	train-mlogloss:1.35803	valid-mlogloss:1.64963
# [10]	train-mlogloss:1.23202	valid-mlogloss:1.52581
# [11]	train-mlogloss:1.11872	valid-mlogloss:1.41311
# [12]	train-mlogloss:1.01836	valid-mlogloss:1.31267
# [13]	train-mlogloss:0.93118	valid-mlogloss:1.22435
# [14]	train-mlogloss:0.85318	valid-mlogloss:1.14476
# [15]	train-mlogloss:0.78315	valid-mlogloss:1.07319
# [16]	train-mlogloss:0.71996	valid-mlogloss:1.00738
# [17]	train-mlogloss:0.66286	valid-mlogloss:0.94733
# [18]	train-mlogloss:0.61107	valid-mlogloss:0.89201
# [19]	train-mlogloss:0.56217	valid-mlogloss:0.83984
# [20]	train-mlogloss:0.51706	valid-mlogloss:0.79104
# [21]	train-mlogloss:0.47593	valid-mlogloss:0.74583
# [22]	train-mlogloss:0.43924	valid-mlogloss:0.70456
# [23]	train-mlogloss:0.40510	valid-mlogloss:0.66559
# [24]	train-mlogloss:0.37323	valid-mlogloss:0.62897
# [25]	train-mlogloss:0.34497	valid-mlogloss:0.59567
# [26]	train-mlogloss:0.31742	valid-mlogloss:0.56312
# [27]	train-mlogloss:0.29258	valid-mlogloss:0.53341
# [28]	train-mlogloss:0.27024	valid-mlogloss:0.50589
# [29]	train-mlogloss:0.24894	valid-mlogloss:0.47941
# [30]	train-mlogloss:0.23036	valid-mlogloss:0.45578
# [31]	train-mlogloss:0.21346	valid-mlogloss:0.43374
# [32]	train-mlogloss:0.19700	valid-mlogloss:0.41223
# [33]	train-mlogloss:0.18262	valid-mlogloss:0.39273
# [34]	train-mlogloss:0.16955	valid-mlogloss:0.37472
# [35]	train-mlogloss:0.15759	valid-mlogloss:0.35781
# [36]	train-mlogloss:0.14664	valid-mlogloss:0.34194
# [37]	train-mlogloss:0.13662	valid-mlogloss:0.32715
# [38]	train-mlogloss:0.12741	valid-mlogloss:0.31321
# [39]	train-mlogloss:0.11895	valid-mlogloss:0.30020
# [40]	train-mlogloss:0.11118	valid-mlogloss:0.28795
# [41]	train-mlogloss:0.10404	valid-mlogloss:0.27654
# [42]	train-mlogloss:0.09746	valid-mlogloss:0.26574
# [43]	train-mlogloss:0.09141	valid-mlogloss:0.25561
# [44]	train-mlogloss:0.08584	valid-mlogloss:0.24605
# [45]	train-mlogloss:0.08070	valid-mlogloss:0.23717
# [46]	train-mlogloss:0.07597	valid-mlogloss:0.22884
# [47]	train-mlogloss:0.07159	valid-mlogloss:0.22096
# [48]	train-mlogloss:0.06755	valid-mlogloss:0.21346
# [49]	train-mlogloss:0.06383	valid-mlogloss:0.20648
# [50]	train-mlogloss:0.06040	valid-mlogloss:0.19983
# [51]	train-mlogloss:0.05724	valid-mlogloss:0.19355
# [52]	train-mlogloss:0.05434	valid-mlogloss:0.18777
# [53]	train-mlogloss:0.05167	valid-mlogloss:0.18229
# [54]	train-mlogloss:0.04919	valid-mlogloss:0.17718
# [55]	train-mlogloss:0.04691	valid-mlogloss:0.17238
# [56]	train-mlogloss:0.04481	valid-mlogloss:0.16780
# [57]	train-mlogloss:0.04288	valid-mlogloss:0.16357
# [58]	train-mlogloss:0.04108	valid-mlogloss:0.15964
# [59]	train-mlogloss:0.03943	valid-mlogloss:0.15594
# [60]	train-mlogloss:0.03789	valid-mlogloss:0.15239
# [61]	train-mlogloss:0.03647	valid-mlogloss:0.14909
# [62]	train-mlogloss:0.03515	valid-mlogloss:0.14599
# [63]	train-mlogloss:0.03392	valid-mlogloss:0.14313
# [64]	train-mlogloss:0.03278	valid-mlogloss:0.14039
# [65]	train-mlogloss:0.03170	valid-mlogloss:0.13779
# [66]	train-mlogloss:0.03069	valid-mlogloss:0.13528
# [67]	train-mlogloss:0.02975	valid-mlogloss:0.13289
# [68]	train-mlogloss:0.02885	valid-mlogloss:0.13066
# [69]	train-mlogloss:0.02801	valid-mlogloss:0.12847
# [70]	train-mlogloss:0.02721	valid-mlogloss:0.12641
# [71]	train-mlogloss:0.02646	valid-mlogloss:0.12447
# [72]	train-mlogloss:0.02574	valid-mlogloss:0.12261
# [73]	train-mlogloss:0.02506	valid-mlogloss:0.12083
# [74]	train-mlogloss:0.02442	valid-mlogloss:0.11910
# [75]	train-mlogloss:0.02380	valid-mlogloss:0.11739
# [76]	train-mlogloss:0.02322	valid-mlogloss:0.11582
# [77]	train-mlogloss:0.02267	valid-mlogloss:0.11428
# [78]	train-mlogloss:0.02215	valid-mlogloss:0.11285
# [79]	train-mlogloss:0.02165	valid-mlogloss:0.11144
# [80]	train-mlogloss:0.02118	valid-mlogloss:0.11009
# [81]	train-mlogloss:0.02073	valid-mlogloss:0.10879
# [82]	train-mlogloss:0.02030	valid-mlogloss:0.10756
# [83]	train-mlogloss:0.01990	valid-mlogloss:0.10637
# [84]	train-mlogloss:0.01952	valid-mlogloss:0.10525
# [85]	train-mlogloss:0.01916	valid-mlogloss:0.10417
# [86]	train-mlogloss:0.01882	valid-mlogloss:0.10317
# [87]	train-mlogloss:0.01850	valid-mlogloss:0.10223
# [88]	train-mlogloss:0.01820	valid-mlogloss:0.10137
# [89]	train-mlogloss:0.01792	valid-mlogloss:0.10049
# [90]	train-mlogloss:0.01765	valid-mlogloss:0.09966
# [91]	train-mlogloss:0.01739	valid-mlogloss:0.09893
# [92]	train-mlogloss:0.01716	valid-mlogloss:0.09823
# [93]	train-mlogloss:0.01693	valid-mlogloss:0.09757
# [94]	train-mlogloss:0.01672	valid-mlogloss:0.09694
# [95]	train-mlogloss:0.01652	valid-mlogloss:0.09640
# [96]	train-mlogloss:0.01634	valid-mlogloss:0.09589
# [97]	train-mlogloss:0.01616	valid-mlogloss:0.09540
# [98]	train-mlogloss:0.01600	valid-mlogloss:0.09490
# [99]	train-mlogloss:0.01585	valid-mlogloss:0.09448
# [100]	train-mlogloss:0.01570	valid-mlogloss:0.09407
# [101]	train-mlogloss:0.01556	valid-mlogloss:0.09366
# [102]	train-mlogloss:0.01543	valid-mlogloss:0.09329
# [103]	train-mlogloss:0.01531	valid-mlogloss:0.09295
# [104]	train-mlogloss:0.01520	valid-mlogloss:0.09265
# [105]	train-mlogloss:0.01509	valid-mlogloss:0.09235
# [106]	train-mlogloss:0.01499	valid-mlogloss:0.09209
# [107]	train-mlogloss:0.01489	valid-mlogloss:0.09185
# [108]	train-mlogloss:0.01480	valid-mlogloss:0.09163
# [109]	train-mlogloss:0.01472	valid-mlogloss:0.09140
# [110]	train-mlogloss:0.01463	valid-mlogloss:0.09119
# [111]	train-mlogloss:0.01455	valid-mlogloss:0.09101
# [112]	train-mlogloss:0.01448	valid-mlogloss:0.09083
# [113]	train-mlogloss:0.01441	valid-mlogloss:0.09066
# [114]	train-mlogloss:0.01434	valid-mlogloss:0.09050
# [115]	train-mlogloss:0.01428	valid-mlogloss:0.09035
# [116]	train-mlogloss:0.01421	valid-mlogloss:0.09020
# [117]	train-mlogloss:0.01416	valid-mlogloss:0.09007
# [118]	train-mlogloss:0.01410	valid-mlogloss:0.08996
# [119]	train-mlogloss:0.01405	valid-mlogloss:0.08984
# [120]	train-mlogloss:0.01400	valid-mlogloss:0.08971
# [121]	train-mlogloss:0.01395	valid-mlogloss:0.08961
# [122]	train-mlogloss:0.01390	valid-mlogloss:0.08953
# [123]	train-mlogloss:0.01386	valid-mlogloss:0.08943
# [124]	train-mlogloss:0.01381	valid-mlogloss:0.08935
# [125]	train-mlogloss:0.01377	valid-mlogloss:0.08927
# [126]	train-mlogloss:0.01373	valid-mlogloss:0.08918
# [127]	train-mlogloss:0.01369	valid-mlogloss:0.08911
# [128]	train-mlogloss:0.01366	valid-mlogloss:0.08905
# [129]	train-mlogloss:0.01362	valid-mlogloss:0.08897
# [130]	train-mlogloss:0.01359	valid-mlogloss:0.08891
# [131]	train-mlogloss:0.01355	valid-mlogloss:0.08887
# [132]	train-mlogloss:0.01352	valid-mlogloss:0.08880
# [133]	train-mlogloss:0.01349	valid-mlogloss:0.08875
# [134]	train-mlogloss:0.01346	valid-mlogloss:0.08870
# [135]	train-mlogloss:0.01343	valid-mlogloss:0.08865
# [136]	train-mlogloss:0.01340	valid-mlogloss:0.08861
# [137]	train-mlogloss:0.01338	valid-mlogloss:0.08858
# [138]	train-mlogloss:0.01335	valid-mlogloss:0.08854
# [139]	train-mlogloss:0.01332	valid-mlogloss:0.08850
# [140]	train-mlogloss:0.01330	valid-mlogloss:0.08847
# [141]	train-mlogloss:0.01327	valid-mlogloss:0.08846
# [142]	train-mlogloss:0.01325	valid-mlogloss:0.08844
# [143]	train-mlogloss:0.01323	valid-mlogloss:0.08842
# [144]	train-mlogloss:0.01320	valid-mlogloss:0.08840
# [145]	train-mlogloss:0.01318	valid-mlogloss:0.08837
# [146]	train-mlogloss:0.01316	valid-mlogloss:0.08835
# [147]	train-mlogloss:0.01314	valid-mlogloss:0.08831
# [148]	train-mlogloss:0.01312	valid-mlogloss:0.08828
# [149]	train-mlogloss:0.01310	valid-mlogloss:0.08826
# [150]	train-mlogloss:0.01308	valid-mlogloss:0.08824
# [151]	train-mlogloss:0.01306	valid-mlogloss:0.08824
# [152]	train-mlogloss:0.01304	valid-mlogloss:0.08824
# [153]	train-mlogloss:0.01302	valid-mlogloss:0.08825
# [154]	train-mlogloss:0.01300	valid-mlogloss:0.08823
# [155]	train-mlogloss:0.01299	valid-mlogloss:0.08820
# [156]	train-mlogloss:0.01297	valid-mlogloss:0.08819
# [157]	train-mlogloss:0.01296	valid-mlogloss:0.08818
# [158]	train-mlogloss:0.01294	valid-mlogloss:0.08816
# [159]	train-mlogloss:0.01292	valid-mlogloss:0.08815
# [160]	train-mlogloss:0.01290	valid-mlogloss:0.08815
# [161]	train-mlogloss:0.01289	valid-mlogloss:0.08814
# [162]	train-mlogloss:0.01287	valid-mlogloss:0.08814
# [163]	train-mlogloss:0.01286	valid-mlogloss:0.08812
# [164]	train-mlogloss:0.01284	valid-mlogloss:0.08813
# [165]	train-mlogloss:0.01283	valid-mlogloss:0.08813
# [166]	train-mlogloss:0.01281	valid-mlogloss:0.08812
# [167]	train-mlogloss:0.01280	valid-mlogloss:0.08812
# [168]	train-mlogloss:0.01279	valid-mlogloss:0.08811
# [169]	train-mlogloss:0.01277	valid-mlogloss:0.08809
# [170]	train-mlogloss:0.01276	valid-mlogloss:0.08809
# [171]	train-mlogloss:0.01275	valid-mlogloss:0.08809
# [172]	train-mlogloss:0.01274	valid-mlogloss:0.08808
# [173]	train-mlogloss:0.01272	valid-mlogloss:0.08808
# [174]	train-mlogloss:0.01271	valid-mlogloss:0.08807
# [175]	train-mlogloss:0.01270	valid-mlogloss:0.08807
# [176]	train-mlogloss:0.01269	valid-mlogloss:0.08805
# [177]	train-mlogloss:0.01268	valid-mlogloss:0.08805
# [178]	train-mlogloss:0.01266	valid-mlogloss:0.08804
# [179]	train-mlogloss:0.01265	valid-mlogloss:0.08803
# [180]	train-mlogloss:0.01264	valid-mlogloss:0.08804
# [181]	train-mlogloss:0.01263	valid-mlogloss:0.08804
# [182]	train-mlogloss:0.01262	valid-mlogloss:0.08803
# [183]	train-mlogloss:0.01261	valid-mlogloss:0.08804
# [184]	train-mlogloss:0.01260	valid-mlogloss:0.08804
# [185]	train-mlogloss:0.01259	valid-mlogloss:0.08804
# [186]	train-mlogloss:0.01258	valid-mlogloss:0.08803
# [187]	train-mlogloss:0.01257	valid-mlogloss:0.08802
# [188]	train-mlogloss:0.01256	valid-mlogloss:0.08802
# [189]	train-mlogloss:0.01255	valid-mlogloss:0.08803
# [190]	train-mlogloss:0.01254	valid-mlogloss:0.08803
# [191]	train-mlogloss:0.01253	valid-mlogloss:0.08803
# [192]	train-mlogloss:0.01252	valid-mlogloss:0.08803
# [193]	train-mlogloss:0.01251	valid-mlogloss:0.08803
# [194]	train-mlogloss:0.01250	valid-mlogloss:0.08803
# [195]	train-mlogloss:0.01249	valid-mlogloss:0.08804
# [196]	train-mlogloss:0.01248	valid-mlogloss:0.08805
# [197]	train-mlogloss:0.01247	valid-mlogloss:0.08805
# [198]	train-mlogloss:0.01247	valid-mlogloss:0.08804
# [199]	train-mlogloss:0.01246	valid-mlogloss:0.08804
# [200]	train-mlogloss:0.01245	valid-mlogloss:0.08805
# [201]	train-mlogloss:0.01244	valid-mlogloss:0.08805
# [202]	train-mlogloss:0.01243	valid-mlogloss:0.08806
# [203]	train-mlogloss:0.01242	valid-mlogloss:0.08805
# [204]	train-mlogloss:0.01242	valid-mlogloss:0.08806
# [205]	train-mlogloss:0.01241	valid-mlogloss:0.08805
# [206]	train-mlogloss:0.01240	valid-mlogloss:0.08805
# [207]	train-mlogloss:0.01239	valid-mlogloss:0.08807
# [208]	train-mlogloss:0.01238	valid-mlogloss:0.08809
# [209]	train-mlogloss:0.01238	valid-mlogloss:0.08810
# [210]	train-mlogloss:0.01237	valid-mlogloss:0.08811
# [211]	train-mlogloss:0.01236	valid-mlogloss:0.08812
# [212]	train-mlogloss:0.01235	valid-mlogloss:0.08812
# [213]	train-mlogloss:0.01235	valid-mlogloss:0.08814
# [214]	train-mlogloss:0.01234	valid-mlogloss:0.08816
# [215]	train-mlogloss:0.01233	valid-mlogloss:0.08816
# [216]	train-mlogloss:0.01232	valid-mlogloss:0.08817
# [217]	train-mlogloss:0.01232	valid-mlogloss:0.08817
# [218]	train-mlogloss:0.01231	valid-mlogloss:0.08817
# [219]	train-mlogloss:0.01231	valid-mlogloss:0.08818
# [220]	train-mlogloss:0.01230	valid-mlogloss:0.08819
# [221]	train-mlogloss:0.01229	valid-mlogloss:0.08820
# [222]	train-mlogloss:0.01228	valid-mlogloss:0.08820
# [223]	train-mlogloss:0.01228	valid-mlogloss:0.08820
# [224]	train-mlogloss:0.01227	valid-mlogloss:0.08823
# [225]	train-mlogloss:0.01226	valid-mlogloss:0.08823
# [226]	train-mlogloss:0.01226	valid-mlogloss:0.08824
# [227]	train-mlogloss:0.01225	valid-mlogloss:0.08824
# [228]	train-mlogloss:0.01224	valid-mlogloss:0.08824
# [229]	train-mlogloss:0.01224	valid-mlogloss:0.08823
# [230]	train-mlogloss:0.01223	valid-mlogloss:0.08825
# [231]	train-mlogloss:0.01223	valid-mlogloss:0.08826
# [232]	train-mlogloss:0.01222	valid-mlogloss:0.08825
# [233]	train-mlogloss:0.01221	valid-mlogloss:0.08825
# [234]	train-mlogloss:0.01221	valid-mlogloss:0.08826
# [235]	train-mlogloss:0.01220	valid-mlogloss:0.08826
# [236]	train-mlogloss:0.01220	valid-mlogloss:0.08827
# [237]	train-mlogloss:0.01219	valid-mlogloss:0.08827
# [238]	train-mlogloss:0.01219	valid-mlogloss:0.08829
# [239]	train-mlogloss:0.01218	valid-mlogloss:0.08829
# [240]	train-mlogloss:0.01218	valid-mlogloss:0.08830
# [241]	train-mlogloss:0.01217	valid-mlogloss:0.08830
# [242]	train-mlogloss:0.01216	valid-mlogloss:0.08832
# [243]	train-mlogloss:0.01216	valid-mlogloss:0.08832
# [244]	train-mlogloss:0.01215	valid-mlogloss:0.08833
# [245]	train-mlogloss:0.01215	valid-mlogloss:0.08833
# [246]	train-mlogloss:0.01214	valid-mlogloss:0.08834
# [247]	train-mlogloss:0.01214	valid-mlogloss:0.08833
# [248]	train-mlogloss:0.01213	valid-mlogloss:0.08834
# [checkpoint] saved /content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints/xgb_fold5_0250.json
# [249]	train-mlogloss:0.01213	valid-mlogloss:0.08834
# [250]	train-mlogloss:0.01212	valid-mlogloss:0.08834
# [251]	train-mlogloss:0.01212	valid-mlogloss:0.08836
# [252]	train-mlogloss:0.01211	valid-mlogloss:0.08836
# [253]	train-mlogloss:0.01211	valid-mlogloss:0.08837
# [254]	train-mlogloss:0.01210	valid-mlogloss:0.08839
# [255]	train-mlogloss:0.01210	valid-mlogloss:0.08839
# [256]	train-mlogloss:0.01209	valid-mlogloss:0.08839
# [257]	train-mlogloss:0.01209	valid-mlogloss:0.08840
# [258]	train-mlogloss:0.01209	valid-mlogloss:0.08841
# [259]	train-mlogloss:0.01208	valid-mlogloss:0.08843
# [260]	train-mlogloss:0.01208	valid-mlogloss:0.08844
# [261]	train-mlogloss:0.01207	valid-mlogloss:0.08846
# [262]	train-mlogloss:0.01207	valid-mlogloss:0.08847
# [263]	train-mlogloss:0.01206	valid-mlogloss:0.08847
# [264]	train-mlogloss:0.01206	valid-mlogloss:0.08848
# [265]	train-mlogloss:0.01205	valid-mlogloss:0.08848
# [266]	train-mlogloss:0.01205	valid-mlogloss:0.08850
# [267]	train-mlogloss:0.01205	valid-mlogloss:0.08850
# [268]	train-mlogloss:0.01204	valid-mlogloss:0.08851
# [269]	train-mlogloss:0.01204	valid-mlogloss:0.08851
# [270]	train-mlogloss:0.01203	valid-mlogloss:0.08851
# [271]	train-mlogloss:0.01203	valid-mlogloss:0.08852
# [272]	train-mlogloss:0.01202	valid-mlogloss:0.08853
# [273]	train-mlogloss:0.01202	valid-mlogloss:0.08853
# [274]	train-mlogloss:0.01202	valid-mlogloss:0.08854
# [275]	train-mlogloss:0.01201	valid-mlogloss:0.08854
# [276]	train-mlogloss:0.01201	valid-mlogloss:0.08855
# [277]	train-mlogloss:0.01200	valid-mlogloss:0.08855
# [278]	train-mlogloss:0.01200	valid-mlogloss:0.08855
# [279]	train-mlogloss:0.01200	valid-mlogloss:0.08857
# [280]	train-mlogloss:0.01199	valid-mlogloss:0.08857
# [281]	train-mlogloss:0.01199	valid-mlogloss:0.08859
# [282]	train-mlogloss:0.01198	valid-mlogloss:0.08858
# [283]	train-mlogloss:0.01198	valid-mlogloss:0.08859
# [284]	train-mlogloss:0.01198	valid-mlogloss:0.08859
# [285]	train-mlogloss:0.01197	valid-mlogloss:0.08859
# [286]	train-mlogloss:0.01197	valid-mlogloss:0.08861
# [287]	train-mlogloss:0.01196	valid-mlogloss:0.08860
# [288]	train-mlogloss:0.01196	valid-mlogloss:0.08861
# ✅ Saved final model: /content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints/xgb_fold5_final.json
# Fold 5 accuracy: 0.9909
# Best iteration (early stop): 188
#
# Mean CV accuracy: 0.9906 ± 0.0005
# All checkpoints & final models in: /content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints

# %%
# === XGBoost CV training with resume + checkpoints + optional timing display ===
# import os, re, glob, json, pickle, time
# import numpy as np
# from pathlib import Path
# from collections import Counter
# from sklearn.model_selection import StratifiedKFold
# from sklearn.metrics import accuracy_score
# import xgboost as xgb
# from xgboost import callback

# # ---------------- CONFIG ----------------
# SAVE_DIR = Path("/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251029-044735/xgb_checkpoints")
# SAVE_DIR.mkdir(parents=True, exist_ok=True)

# NUM_CLASS = len(le.classes_)      # from your LabelEncoder
# N_BOOST_ROUNDS = 1000             # cap on total trees
# EARLY_STOPPING_ROUNDS = 100       # stop if no improvement
# CHECKPOINT_EVERY = 250            # save every N rounds
# RANDOM_STATE = 42
# N_SPLITS = 5                      # auto-lowered if rare class < 5
# USE_TQDM = True                   # <<< OPTIONAL: set to False to disable progress bar
# # ---------------------------------------

# # ---- optional tqdm import ----
# if USE_TQDM:
#     try:
#         from tqdm.notebook import tqdm
#     except Exception:
#         !pip -q install tqdm
#         from tqdm.notebook import tqdm

# # ---- periodic saver callback ----
# class PeriodicSaver(callback.TrainingCallback):
#     """Save booster every `every` rounds to SAVE_DIR / f'{name}_{iter:04d}.json'."""
#     def __init__(self, save_dir: Path, name: str, every: int):
#         self.save_dir = Path(save_dir); self.name = name; self.every = int(every)
#     def after_iteration(self, model, epoch: int, evals_log) -> bool:
#         it = epoch + 1
#         if it % self.every == 0:
#             path = self.save_dir / f"{self.name}_{it:04d}.json"
#             model.save_model(str(path))
#             print(f"[checkpoint] saved {path}")
#         return False

# def latest_checkpoint_for_fold(save_dir: Path, fold: int):
#     """Return path to latest checkpoint (json) for this fold, or None."""
#     pattern = str(save_dir / f"xgb_fold{fold}_*.json")
#     candidates = glob.glob(pattern)
#     if not candidates: return None
#     rx = re.compile(rf"xgb_fold{fold}_(\d+)\.json$")
#     best, best_iter = None, -1
#     for p in candidates:
#         m = rx.search(os.path.basename(p))
#         if m:
#             it = int(m.group(1))
#             if it > best_iter: best, best_iter = p, it
#     return best

# def score_fold(booster: xgb.Booster, X_va, y_va):
#     dvalid = xgb.DMatrix(X_va, label=y_va)
#     best_it = getattr(booster, "best_iteration", None)
#     y_prob = booster.predict(dvalid, iteration_range=(0, best_it + 1) if best_it is not None else None)
#     y_pred = np.argmax(y_prob, axis=1)
#     return accuracy_score(y_va, y_pred), best_it

# # --- adjust #folds if rare class is too small ---
# min_per_class = min(Counter(y_train_enc).values())
# actual_splits = min(N_SPLITS, max(2, min_per_class))
# print(f"Using {actual_splits}-fold CV (min per class = {min_per_class})")

# kf = StratifiedKFold(n_splits=actual_splits, shuffle=True, random_state=RANDOM_STATE)
# fold_accs, fold_times = [], []

# # Common XGBoost params (GPU in 3.1.1 via device='cuda'; falls back to CPU if not available)
# params = {
#     "objective": "multi:softprob",
#     "num_class": NUM_CLASS,
#     "eval_metric": "mlogloss",
#     "max_depth": 4,
#     "learning_rate": 0.1,
#     "subsample": 0.9,
#     "colsample_bytree": 0.9,
#     "reg_lambda": 1.0,
#     "tree_method": "hist",   # works on both CPU and GPU in 3.x
#     "device": "cuda",        # use A100 if available
#     "seed": RANDOM_STATE,
# }

# progress = None
# if USE_TQDM:
#     progress = tqdm(total=actual_splits, desc="Cross-validation", unit="fold")

# total_start = time.time()

# for fold, (train_idx, val_idx) in enumerate(kf.split(X_train, y_train_enc), 1):
#     fold_start = time.time()
#     final_json = SAVE_DIR / f"xgb_fold{fold}_final.json"
#     print(f"\n===== Fold {fold} =====")

#     X_tr, X_va = X_train[train_idx], X_train[val_idx]
#     y_tr, y_va = y_train_enc[train_idx], y_train_enc[val_idx]

#     # If final model exists, skip training and just score (fast re-runs)
#     if final_json.exists():
#         print(f"🔁 Found completed fold model, skipping training: {final_json.name}")
#         booster = xgb.Booster(); booster.load_model(str(final_json))
#         acc, best_it = score_fold(booster, X_va, y_va)
#         fold_accs.append(acc)
#         fold_time = time.time() - fold_start
#         fold_times.append(fold_time)
#         print(f"Fold {fold} accuracy: {acc:.4f} | best_it: {best_it if best_it is not None else '-'}")
#         print(f"⏱️  Fold {fold} took {fold_time:.2f}s")
#         if progress:
#             eta = (actual_splits - fold) * (np.mean(fold_times) if fold_times else 0)
#             progress.update(1)
#             progress.set_postfix({"fold": fold, "acc": f"{acc:.4f}", "best_it": best_it if best_it is not None else "-",
#                                   "ETA (s)": f"{eta:.1f}"})
#         continue

#     dtrain, dvalid = xgb.DMatrix(X_tr, label=y_tr), xgb.DMatrix(X_va, label=y_va)
#     evals = [(dtrain, "train"), (dvalid, "valid")]

#     resume_path = latest_checkpoint_for_fold(SAVE_DIR, fold)
#     print(f"{'➡️  Resuming from ' + resume_path if resume_path else '➡️  No checkpoint found; starting fresh.'}")

#     booster = xgb.train(
#         params=params,
#         dtrain=dtrain,
#         num_boost_round=N_BOOST_ROUNDS,
#         evals=evals,
#         early_stopping_rounds=EARLY_STOPPING_ROUNDS,
#         callbacks=[PeriodicSaver(SAVE_DIR, name=f"xgb_fold{fold}", every=CHECKPOINT_EVERY)],
#         xgb_model=resume_path if resume_path else None,
#         verbose_eval=100
#     )

#     # Save final model for this fold
#     booster.save_model(str(final_json))
#     print(f"✅ Saved final model: {final_json}")

#     # Evaluate this fold
#     acc, best_it = score_fold(booster, X_va, y_va)
#     fold_accs.append(acc)
#     print(f"Fold {fold} accuracy: {acc:.4f}")
#     if best_it is not None:
#         print(f"Best iteration (early stop): {best_it}")

#     # Timing + ETA
#     fold_time = time.time() - fold_start
#     fold_times.append(fold_time)
#     eta = (actual_splits - fold) * np.mean(fold_times)
#     print(f"⏱️  Fold {fold} took {fold_time:.2f}s.  Estimated remaining ≈ {eta:.1f}s ({eta/60:.1f} min)")

#     if progress:
#         progress.update(1)
#         progress.set_postfix({"fold": fold, "acc": f"{acc:.4f}", "best_it": best_it if best_it is not None else "-",
#                               "ETA (s)": f"{eta:.1f}"})

# if progress:
#     progress.close()

# total_time = time.time() - total_start
# print(f"\nMean CV accuracy: {np.mean(fold_accs):.4f} ± {np.std(fold_accs):.4f}")
# print(f"Total training time: {total_time:.1f}s ({total_time/60:.1f} min)")
# print(f"All checkpoints & final models in: {SAVE_DIR}")

# %% [markdown]
# # Step 5: Evaluation with 20% validation data

# %%
import xgboost as xgb
from pathlib import Path
import numpy as np

SAVE_DIR = Path("/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints")

# find all final models
final_models = sorted(SAVE_DIR.glob("xgb_fold*_final.json"))
print(f"Found {len(final_models)} fold models")
# Out:
# Found 5 fold models

# %%
dval = xgb.DMatrix(X_val, label=y_val_enc)

# %%
probs = []
for path in final_models:
    booster = xgb.Booster()
    booster.load_model(str(path))
    best_it = getattr(booster, "best_iteration", None)
    y_prob = booster.predict(dval, iteration_range=(0, best_it + 1) if best_it is not None else None)
    probs.append(y_prob)

# average across folds
y_prob_mean = np.mean(probs, axis=0)
y_pred = np.argmax(y_prob_mean, axis=1)

# %%
# print(y_prob_mean)
print(y_prob_mean.shape)
print(y_pred.shape)
# Out:
# (34860, 1660)
# (34860,)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

val_acc = accuracy_score(y_val_enc, y_pred)
print(f"Final validation accuracy (ensemble of 5 folds): {val_acc:.4f}")

# (Optional) confusion matrix if you want to inspect per-class results
# cm = confusion_matrix(y_val_enc, y_pred)
# print(cm)
# Out:
# Final validation accuracy (ensemble of 5 folds): 0.9922

# %% [markdown]
# # Step 6: PubMed External Evaluation
#
#
# *   First process the pubmed data with Llama embedding and kmeans clustering and save it for reproducibility.
# *   Run predictions using the 5-fold ensemble, output top 10/20 syndromes for each case.

# %%
import json
import numpy as np
import pandas as pd
from pathlib import Path
from tqdm.auto import tqdm
from scipy.sparse import csr_matrix
from sklearn.metrics import accuracy_score, top_k_accuracy_score
import xgboost as xgb

# --------------------------------------------------
# Paths
# --------------------------------------------------
BASE = "/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311"
SAVE_DIR = Path(BASE) / "xgb_checkpoints"

PUBMED_XLSX   = Path(BASE) / "PUBMED_cohort.xlsx"
ASSIGN_CSV    = Path(BASE) / "pubmed_symptom_cluster_assignments.csv"
SYM_VOCAB_JSON = Path(BASE) / "symptom_vocab.json"
LABEL_MAP_JSON = Path(BASE) / "label_map.json"

label_col = "OMIM Diagnosis"   # ground-truth label column in PUBMED_cohort.xlsx

# --------------------------------------------------
# 1. Load data
# --------------------------------------------------
df_pub = pd.read_excel(PUBMED_XLSX)
assign_df = pd.read_csv(ASSIGN_CSV)

with open(SYM_VOCAB_JSON, "r", encoding="utf-8") as f:
    symptom_vocab_list = json.load(f)   # list of cluster_ids, len = 9883

with open(LABEL_MAP_JSON, "r", encoding="utf-8") as f:
    label_map = json.load(f)   # {disease_name: class_index}

print("PubMed rows:", len(df_pub))
print("symptom_vocab_list length:", len(symptom_vocab_list))
print("Example label_map items:", list(label_map.items())[:5])

# --------------------------------------------------
# 2. Filter PubMed rows to only labels the model knows
# --------------------------------------------------
pub_labels_raw = df_pub[label_col].astype(str)
missing_labels = [x for x in pub_labels_raw.unique() if x not in label_map]
print("Labels in PubMed not in label_map:", missing_labels)
print("Total unique missing labels:", len(missing_labels))

valid_mask = pub_labels_raw.isin(label_map.keys())
print("Total cases:", len(df_pub))
print("Valid cases:", valid_mask.sum())
print("Dropped cases:", (~valid_mask).sum())

df_pub_filtered = df_pub[valid_mask].reset_index(drop=True)
y_pubmed = df_pub_filtered[label_col].astype(str).map(label_map).values
print("df_pub_filtered shape:", df_pub_filtered.shape)
print("y_pubmed shape:", y_pubmed.shape)
print("First 10 y_pubmed:", y_pubmed[:10])

# --------------------------------------------------
# 3. Reconstruct vocab: cluster_id -> feature_index
#    symptom_vocab_list[i] = cluster_id_for_feature_i
# --------------------------------------------------
sym_vocab = {str(cluster_id): idx
             for idx, cluster_id in enumerate(symptom_vocab_list)}
print("sym_vocab size (should be 9883):", len(sym_vocab))

# --------------------------------------------------
# 4. Build symptom -> cluster_id mapping from assignment CSV
# --------------------------------------------------
def norm_text(s: str) -> str:
    s = str(s)
    s = s.strip()
    s = " ".join(s.split())   # collapse multiple spaces
    return s

assign_df["symptom_norm"] = assign_df["symptom"].apply(norm_text)
symptom_to_cluster = dict(zip(assign_df["symptom_norm"], assign_df["cluster_id"]))
print("symptom_to_cluster size:", len(symptom_to_cluster))

# quick sanity check for one known symptom
print("Example assignment row:", assign_df.head(3))

# --------------------------------------------------
# 5. Build X_pubmed_filtered (one row per PubMed case,
#    one column per feature index (0..9882), using cluster_id->feature_index mapping
# --------------------------------------------------
n_cases = len(df_pub_filtered)
vocab_size = len(sym_vocab)

indptr = [0]
indices = []
data = []

def parse_symptoms(cell):
    if pd.isna(cell):
        return []
    return [s.strip() for s in str(cell).split(";") if s.strip()]

for _, row in tqdm(df_pub_filtered.iterrows(), total=n_cases, desc="Building X_pubmed_filtered"):
    raw_syms = parse_symptoms(row["Symptoms"])

    feat_set = set()

    for s in raw_syms:
        ns = norm_text(s)
        cid = symptom_to_cluster.get(ns)   # cluster_id (0..9999)
        if cid is None:
            continue

        cid_key = str(cid)
        j = sym_vocab.get(cid_key)         # feature index (0..9882)
        if j is not None:
            feat_set.add(j)

    feat_indices = sorted(feat_set)
    indices.extend(feat_indices)
    data.extend([1] * len(feat_indices))
    indptr.append(len(indices))

X_pubmed_filtered = csr_matrix(
    (data, indices, indptr),
    shape=(n_cases, vocab_size),
    dtype=np.float32,
)

print("X_pubmed_filtered shape:", X_pubmed_filtered.shape)

# Sanity: nonzero features per row
nnz_per_row = X_pubmed_filtered.getnnz(axis=1)
print("Avg active features per case:", nnz_per_row.mean())
print("First 10 nnz counts:", nnz_per_row[:10])

# Optional: inspect first row
inv_vocab = {v: int(k) for k, v in sym_vocab.items()}  # feature_index -> cluster_id
i = 0
row0 = X_pubmed_filtered[i]
active_feats0 = row0.nonzero()[1]
active_clusters0 = [inv_vocab[j] for j in active_feats0]

print("\nRow 0 Diagnosis:", df_pub_filtered.iloc[0][label_col])
print("Row 0 Symptoms:", df_pub_filtered.iloc[0]["Symptoms"])
print("Row 0 active feature indices:", active_feats0)
print("Row 0 active cluster IDs:", active_clusters0)

# --------------------------------------------------
# 6. Load 5 XGBoost models and evaluate ensemble
# --------------------------------------------------
# Adjust the glob pattern to match your filenames, e.g. "xgb_fold*_final.json"
model_paths = sorted(SAVE_DIR.glob("xgb_fold*_final.json"))
print("Model paths found:", model_paths)

models = []
for p in model_paths:
    booster = xgb.Booster()
    booster.load_model(str(p))
    models.append(booster)
print("Loaded", len(models), "models.")

dtest = xgb.DMatrix(X_pubmed_filtered)

fold_probs = []
for model in models:
    probs = model.predict(dtest)   # shape: (n_cases, n_classes)
    fold_probs.append(probs)

fold_probs = np.stack(fold_probs, axis=0)   # (n_folds, n_cases, n_classes)
avg_probs = fold_probs.mean(axis=0)         # (n_cases, n_classes)

y_pred = np.argmax(avg_probs, axis=1)

all_classes = list(label_map.values())  # 0..1659

acc = accuracy_score(y_pubmed, y_pred)
top10 = top_k_accuracy_score(y_pubmed, avg_probs, k=10, labels=all_classes)
top20 = top_k_accuracy_score(y_pubmed, avg_probs, k=20, labels=all_classes)

print("\nEnsemble Accuracy:", acc)
print("Top-10 Accuracy:", top10)
print("Top-20 Accuracy:", top20)
# Out:
# PubMed rows: 101
# symptom_vocab_list length: 9883
# Example label_map items: [('2,4-DIENOYL-CoA REDUCTASE DEFICIENCY; DECRD', 0), ('2-METHYLBUTYRYL-CoA DEHYDROGENASE DEFICIENCY', 1), ('3-HYDROXY-3-METHYLGLUTARYL-CoA LYASE DEFICIENCY; HMGCLD', 2), ('3-HYDROXYACYL-CoA DEHYDROGENASE DEFICIENCY', 3), ('3-HYDROXYISOBUTYRYL-CoA HYDROLASE DEFICIENCY; HIBCHD', 4)]
# Labels in PubMed not in label_map: ['CORONARY ARTERY DISEASE, AUTOSOMAL DOMINANT 2; ADCAD2', 'INTELLECTUAL DEVELOPMENTAL DISORDER, AUTOSOMAL DOMINANT 39; MRD39', 'INTELLECTUAL DEVELOPMENTAL DISORDER, AUTOSOMAL DOMINANT 61; MRD61', 'INFLAMMATORY BOWEL DISEASE (CROHN DISEASE) 1; IBD1', 'NEUROFIBROMATOSIS, TYPE I; NF1', 'MELANOCYTIC NEVUS SYNDROME, CONGENITAL; CMNS', 'SIFRIM-HITZ-WEISS SYNDROME; SIHIWES', 'FIBROBLAST GROWTH FACTOR 13; FGF13', 'INOSITOL POLYPHOSPHATE-4-PHOSPHATASE, TYPE I, 107-KD; INPP4A', 'CASGID SYNDROME; CASGID']
# Total unique missing labels: 10
# Total cases: 101
# Valid cases: 90
# Dropped cases: 11
# df_pub_filtered shape: (90, 5)
# y_pubmed shape: (90,)
# First 10 y_pubmed: [446 375 361 393 419 371 414 446 359 394]
# sym_vocab size (should be 9883): 9883
# symptom_to_cluster size: 1205
# Example assignment row:                                              symptom  cluster_id  similarity  \
# 0            Epilepsy (present in 92.2% of patients)        8039    0.753811
# 1      Median age at seizure onset: 2 years 6 months        4691    0.879674
# 2  Multiple seizure types (generalized onset toni...        9272    0.900295
#
#                                         symptom_norm
# 0            Epilepsy (present in 92.2% of patients)
# 1      Median age at seizure onset: 2 years 6 months
# 2  Multiple seizure types (generalized onset toni...
# Building X_pubmed_filtered:   0%|          | 0/90 [00:00<?, ?it/s]
# X_pubmed_filtered shape: (90, 9883)
# Avg active features per case: 13.78888888888889
# First 10 nnz counts: [17  7 12 11 20 11  6  1  5 10]
#
# Row 0 Diagnosis: DEVELOPMENTAL AND EPILEPTIC ENCEPHALOPATHY 94; DEE94
# Row 0 Symptoms: Epilepsy (present in 92.2% of patients); Median age at seizure onset: 2 years 6 months; Multiple seizure types (generalized onset tonic-clonic, absences, myoclonic, focal-onset, atonic, myoclonic-atonic, tonic, epileptic spasms, myoclonic-clonic); Single seizure types (generalized onset tonic-clonic, absences, focal, myoclonic, myoclonic-atonic); History of febrile seizures; Status epilepticus (SE) (convulsive, nonconvulsive, or both); Prevalent epilepsy type: generalized (75.5%), combined generalized and focal (22.3%), focal (2.2%); Aggressive behavior; Attention Deficit Hyperactivity Disorder (ADHD); Autism spectrum disorder (ASD) / autistic features; Specific Learning Disorder (SLD); Obsessive-Compulsive Disorder (OCD); Psychotic symptoms; Tourette's syndrome; Bipolar disorder; Childhood-onset schizophrenia; Brain MRI findings: normal (majority), or cerebellar hypoplasia, cerebellar vermis hypoplasia, cerebellar atrophy, Arnold-Chiari type I malformation, white matter hyperintensity.
# Row 0 active feature indices: [ 214  236  409  613  867 1009 1197 2079 2099 3409 3557 4642 4645 7943
#  8049 9160 9842]
# Row 0 active cluster IDs: [214, 236, 410, 615, 870, 1012, 1201, 2090, 2110, 3439, 3590, 4691, 4694, 8039, 8146, 9272, 9959]
# Model paths found: [PosixPath('/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints/xgb_fold1_final.json'), PosixPath('/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints/xgb_fold2_final.json'), PosixPath('/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints/xgb_fold3_final.json'), PosixPath('/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints/xgb_fold4_final.json'), PosixPath('/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints/xgb_fold5_final.json')]
# Loaded 5 models.
#
# Ensemble Accuracy: 0.011111111111111112
# Top-10 Accuracy: 0.1
# Top-20 Accuracy: 0.13333333333333333

# %% [markdown]
# # Step 7: Clinical Data External Evaluation

# %%
import json
import numpy as np
import pandas as pd
from pathlib import Path
from tqdm.auto import tqdm
from scipy.sparse import csr_matrix
from sklearn.metrics import accuracy_score, top_k_accuracy_score
import xgboost as xgb

# --------------------------------------------------
# Paths
# --------------------------------------------------
BASE = "/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311"
SAVE_DIR = Path(BASE) / "xgb_checkpoints"

CLINICAL_XLSX    = Path(BASE) / "clinical_cohort.xlsx"
ASSIGN_CSV       = Path(BASE) / "clinical_symptom_cluster_assignments.csv"
SYM_VOCAB_JSON   = Path(BASE) / "symptom_vocab.json"
LABEL_MAP_JSON   = Path(BASE) / "label_map.json"

label_col = "OMIM-Diagnosis"   # ground-truth label column in Clinical_cohort.xlsx

# --------------------------------------------------
# 1. Load data
# --------------------------------------------------
df_clin = pd.read_excel(CLINICAL_XLSX)
assign_df = pd.read_csv(ASSIGN_CSV)

with open(SYM_VOCAB_JSON, "r", encoding="utf-8") as f:
    symptom_vocab_list = json.load(f)   # list of cluster_ids, len = 9883

with open(LABEL_MAP_JSON, "r", encoding="utf-8") as f:
    label_map = json.load(f)   # {disease_name: class_index}

print("Clinical rows:", len(df_clin))
print("symptom_vocab_list length:", len(symptom_vocab_list))
print("Example label_map items:", list(label_map.items())[:5])

# --------------------------------------------------
# 2. Filter clinical rows to only labels the model knows
# --------------------------------------------------
clin_labels_raw = df_clin[label_col].astype(str)
missing_labels = [x for x in clin_labels_raw.unique() if x not in label_map]
print("Labels in Clinical not in label_map:", missing_labels)
print("Total unique missing labels:", len(missing_labels))

valid_mask = clin_labels_raw.isin(label_map.keys())
print("Total cases (clinical):", len(df_clin))
print("Valid cases (clinical):", valid_mask.sum())
print("Dropped cases (clinical):", (~valid_mask).sum())

df_clin_filtered = df_clin[valid_mask].reset_index(drop=True)
y_clinical = df_clin_filtered[label_col].astype(str).map(label_map).values
print("df_clin_filtered shape:", df_clin_filtered.shape)
print("y_clinical shape:", y_clinical.shape)
print("First 10 y_clinical:", y_clinical[:10])

# --------------------------------------------------
# 3. Reconstruct vocab: cluster_id -> feature_index
#    symptom_vocab_list[i] = cluster_id_for_feature_i
# --------------------------------------------------
sym_vocab = {str(cluster_id): idx
             for idx, cluster_id in enumerate(symptom_vocab_list)}
print("sym_vocab size (should be 9883):", len(sym_vocab))

# --------------------------------------------------
# 4. Build symptom -> cluster_id mapping from assignment CSV
# --------------------------------------------------
def norm_text(s: str) -> str:
    s = str(s)
    s = s.strip()
    s = " ".join(s.split())   # collapse multiple spaces
    return s

assign_df["symptom_norm"] = assign_df["symptom"].apply(norm_text)
symptom_to_cluster = dict(zip(assign_df["symptom_norm"], assign_df["cluster_id"]))
print("symptom_to_cluster size (clinical):", len(symptom_to_cluster))

# quick sanity check for assignment file
print("Example assignment rows (clinical):")
print(assign_df.head(3))

# --------------------------------------------------
# 5. Build X_clinical_filtered (one row per clinical case,
#    one column per feature index (0..9882), using cluster_id->feature_index mapping
# --------------------------------------------------
n_cases = len(df_clin_filtered)
vocab_size = len(sym_vocab)

indptr = [0]
indices = []
data = []

def parse_symptoms(cell):
    if pd.isna(cell):
        return []
    return [s.strip() for s in str(cell).split(",") if s.strip()]

for _, row in tqdm(df_clin_filtered.iterrows(), total=n_cases, desc="Building X_clinical_filtered"):
    raw_syms = parse_symptoms(row["Symptoms"])   # change column name if clinical uses a different one

    feat_set = set()

    for s in raw_syms:
        ns = norm_text(s)
        cid = symptom_to_cluster.get(ns)   # cluster_id (0..9999)
        if cid is None:
            continue

        cid_key = str(cid)
        j = sym_vocab.get(cid_key)         # feature index (0..9882)
        if j is not None:
            feat_set.add(j)

    feat_indices = sorted(feat_set)
    indices.extend(feat_indices)
    data.extend([1] * len(feat_indices))
    indptr.append(len(indices))

X_clinical_filtered = csr_matrix(
    (data, indices, indptr),
    shape=(n_cases, vocab_size),
    dtype=np.float32,
)

print("X_clinical_filtered shape:", X_clinical_filtered.shape)

# Sanity: nonzero features per row
nnz_per_row = X_clinical_filtered.getnnz(axis=1)
print("Avg active features per clinical case:", nnz_per_row.mean())
print("First 10 nnz counts (clinical):", nnz_per_row[:10])

# Optional: inspect first row
inv_vocab = {v: int(k) for k, v in sym_vocab.items()}  # feature_index -> cluster_id
i = 0
row0 = X_clinical_filtered[i]
active_feats0 = row0.nonzero()[1]
active_clusters0 = [inv_vocab[j] for j in active_feats0]

print("\n[Clinical] Row 0 Diagnosis:", df_clin_filtered.iloc[0][label_col])
print("[Clinical] Row 0 Symptoms:", df_clin_filtered.iloc[0]["Symptoms"])
print("[Clinical] Row 0 active feature indices:", active_feats0)
print("[Clinical] Row 0 active cluster IDs:", active_clusters0)

# --------------------------------------------------
# 6. Load 5 XGBoost models and evaluate ensemble on clinical cohort
# --------------------------------------------------
# Adjust the glob pattern to match your filenames, e.g. "xgb_fold*_final.json"
model_paths = sorted(SAVE_DIR.glob("xgb_fold*_final.json"))
print("Model paths found:", model_paths)

models = []
for p in model_paths:
    booster = xgb.Booster()
    booster.load_model(str(p))
    models.append(booster)
print("Loaded", len(models), "models.")

dtest = xgb.DMatrix(X_clinical_filtered)

fold_probs = []
for model in models:
    probs = model.predict(dtest)   # shape: (n_cases, n_classes)
    fold_probs.append(probs)

fold_probs = np.stack(fold_probs, axis=0)   # (n_folds, n_cases, n_classes)
avg_probs = fold_probs.mean(axis=0)         # (n_cases, n_classes)

y_pred = np.argmax(avg_probs, axis=1)

all_classes = list(label_map.values())  # 0..1659

acc = accuracy_score(y_clinical, y_pred)
top10 = top_k_accuracy_score(y_clinical, avg_probs, k=10, labels=all_classes)
top20 = top_k_accuracy_score(y_clinical, avg_probs, k=20, labels=all_classes)

print("\n[Clinical] Ensemble Accuracy:", acc)
print("[Clinical] Top-10 Accuracy:", top10)
print("[Clinical] Top-20 Accuracy:", top20)
# Out:
# Clinical rows: 107
# symptom_vocab_list length: 9883
# Example label_map items: [('2,4-DIENOYL-CoA REDUCTASE DEFICIENCY; DECRD', 0), ('2-METHYLBUTYRYL-CoA DEHYDROGENASE DEFICIENCY', 1), ('3-HYDROXY-3-METHYLGLUTARYL-CoA LYASE DEFICIENCY; HMGCLD', 2), ('3-HYDROXYACYL-CoA DEHYDROGENASE DEFICIENCY', 3), ('3-HYDROXYISOBUTYRYL-CoA HYDROLASE DEFICIENCY; HIBCHD', 4)]
# Labels in Clinical not in label_map: ['EPILEPSY, FAMILIAL TEMPORAL LOBE, 1; ETL1\n']
# Total unique missing labels: 1
# Total cases (clinical): 107
# Valid cases (clinical): 102
# Dropped cases (clinical): 5
# df_clin_filtered shape: (102, 10)
# y_clinical shape: (102,)
# First 10 y_clinical: [ 184  184 1264  309  580 1655  925   76   46  754]
# sym_vocab size (should be 9883): 9883
# symptom_to_cluster size (clinical): 336
# Example assignment rows (clinical):
#                    symptom  cluster_id  similarity             symptom_norm
# 0           tonic seizures        1990    0.962361           tonic seizures
# 1  febrile seizures during        1012    0.962212  febrile seizures during
# 2             abnormal EEG        4997    0.980745             abnormal EEG
# Building X_clinical_filtered:   0%|          | 0/102 [00:00<?, ?it/s]
# X_clinical_filtered shape: (102, 9883)
# Avg active features per clinical case: 6.107843137254902
# First 10 nnz counts (clinical): [ 8  6  9 10  5  5  4  7  6  4]
#
# [Clinical] Row 0 Diagnosis: CHROMOSOME 22q11.2 DELETION SYNDROME, DISTAL
# [Clinical] Row 0 Symptoms: tonic seizures,  febrile seizures during, abnormal EEG, developmental delays, anxiety,Short statue, dysmorphic face,cleft palate
# [Clinical] Row 0 active feature indices: [   0  302 1009 1979 2417 4945 5135 7074]
# [Clinical] Row 0 active cluster IDs: [0, 303, 1012, 1990, 2435, 4997, 5188, 7156]
# Model paths found: [PosixPath('/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints/xgb_fold1_final.json'), PosixPath('/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints/xgb_fold2_final.json'), PosixPath('/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints/xgb_fold3_final.json'), PosixPath('/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints/xgb_fold4_final.json'), PosixPath('/content/drive/MyDrive/Stanford/CS229/Final Project/llama+kmeans_synthetic_cases_20251128-122311/xgb_checkpoints/xgb_fold5_final.json')]
# Loaded 5 models.
#
# [Clinical] Ensemble Accuracy: 0.06862745098039216
# [Clinical] Top-10 Accuracy: 0.19607843137254902
# [Clinical] Top-20 Accuracy: 0.28431372549019607

# %% [markdown]
# # Summary - XGBoost with 1: 101 dataset
#
# **PubMed Data**
#
# Ensemble Accuracy: 0.011111111111111112 \
# Top-10 Accuracy: 0.1 \
# Top-20 Accuracy: 0.13333333333333333
#
# **Stanford Clinical Data**
#
# Ensemble Accuracy: 0.06862745098039216 \
# Top-10 Accuracy: 0.19607843137254902 \
# Top-20 Accuracy: 0.28431372549019607
